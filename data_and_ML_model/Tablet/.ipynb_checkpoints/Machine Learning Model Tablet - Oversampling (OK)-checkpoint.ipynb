# %% [markdown]
# # Modelo de Detección de la Dislexia aplicando Machine Learning

# %% [markdown]
# Se va a desarrollar un modelo en Machine Learning que sea capaz de detectar si, tras contestar a 32 questiones y teniendo en cuenta el género, la lengua y la edad, una persona es disléxica o no. Cada modelo se va a entrenar y testear con dos datasets distintos: desktop.csv (Train) y tablet.csv (Test).
#
#
# Para ello se va a emplear Machine Learning, importando las librerías de python. Los algoritmos que se van a implementar son:
# 1. K-Nearest Neighbors
# 2. Logistic Regression
# 3. Support Vector Machines
# 4. Random Forest
# 5. Tree Decision
#
# Y finalmente, en caso de que de tiempo:
#
# 6. Neural Networks

# %% [markdown]
# A contiuación, se van a importar las librerías necesarias para desarrollar el modelo de Machine Learning:
# - Pandas: proporcina herramientas para el análisis de datos. Mediante esta herramienta se va leer el documento .csv donde se encuentran los datos y se van a manipular con el propósito de diseñar el modelo de Mchine Learning.
# - NumPy y Matplotlib: se emplearán para el análisis y la visualización de datos. NumPy permite realizar operación y  matemáticas y manejar datos numéricos de manera eficiente y efectiva. Por otro lado, Matplotlib permite crear gráficas para visualizar los datos de manera simple y clara.
# - Seaborn: al igual que Matplotlib, se trata de una librería de visualización de datos. Sin embargo, ofrece una visualización estadística, la cua va a ser de gran utilidad para analizar la distribución de los datos.
# - Warnings: gestionará las advertencias que surjan durante la ejecución del programa. En concreto se va a hacer uso de `warnings.filterwarnings('ignore')` consiguiendo ignorar las posibles advertencias.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
# %matplotlib inline 
warnings.filterwarnings('ignore')

# %% [markdown]
# A su vez, para el entrenamiento y el testeo de los distintos algoritmos de Machine Learning, se van a importar las librerías **Scikit-Learn** y para el manejo de desproporción entre casos positivos y negativos se va a importar **Imbalanced-Learn**.

# %%
#!pip install -U scikit-learn
#!pip install -U imbalanced-learn

# %%
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE
from sklearn import preprocessing
from sklearn.model_selection import KFold

# %% [markdown]
# ## Modeling Preparation

# %% [markdown]
# Se va a comenzar leyendo los datos y exportándolos a las variables *train_df* y *test_df*. Estos datasets van a contener la información con la que se va a construir el modelo. Mediante la librería **pandas** se va a acceder a ellos, siendo capaz de:
# - Comprobar si existen valores nulos
# - Transformar todos los datos a valores numéricos
# - Gestionar los valores nulos
# - Analizar si hay variedad dentro de cada dataset
#
# La información que se va a obtener de cada dataset es:
#
# 1. Genero (hombre o mujer)
# 2. Lengua nativa es el español
# 3. Lengua nativa distinta al español
# 4. Edad
# 5. Información relacionada con las preguntas
# 6. Disléxico: sí o no
#
# La información relacionada con las preguntas contiene el número de clicks que se realizan en cada ejercicio (*Clicks*), diferenciando en respuestas correctas (*Hits*) e incorrectas (*Misses*). A su vez, se cuenta con el resultado final (*Score*), que se obtiene a partir de la cantidad de aciertos por cuestión, junto con la precisión de la respuesta (*Accuracy = Hits/Clicks*) y el ratio de fallo (*Missrate = Misses/Clicks*).
#
# Mediante estos valores se pretende predecir si una persona tiene dislexia o no.

# %%
data = pd.read_csv("../data/Dyt-tablet.csv", delimiter=";")
pd.set_option("display.max_columns" , None)

pd.set_option("display.max_columns" , None)
pd.set_option("display.max_rows" , None)

# %%
# first look train dataset
data.head()
data.iloc[:, :10].dtypes
data.shape
# Out:
# (1395, 197)

# %% [markdown]
# Se ha creado una función `prep_Data(df)`que toma como atributo de entrada un dataset y transforma los valores de las columnas *Gender, Nativelang, Otherlang y Dyslexia* en 0's o 1's, en función de su valor incial. De esta forma solo se trabajará con valores numéricos.

# %%
def prep_Data(df) :
    #ds.column: access to the column specified
    #map(): itarates through the column specified
    df['Gender'] = df.Gender.map({'Male': 0, 'Female': 1})
    df['Nativelang'] = df.Nativelang.map({'No': 0, 'Yes': 1})
    df['Otherlang'] = df.Otherlang.map({'No': 0, 'Yes': 1})
    df['Dyslexia'] = df.Dyslexia.map({'No': 0, 'Yes': 1})

# %%
#transform data
prep_Data(data)

# %% [markdown]
# Al contar con una desproporción muy elevada entre casos positivos y negativos de dislexia entre los datos se va a optar por aumentar el número de datos del dataset, mediante la librería **RandomOverSampler**, de forma que la cantidad de sies sea igual que la de noes.

# %%
count_D_no, count_D_yes = data.Dyslexia.value_counts()

# Divide by class
D_no_df = data[data['Dyslexia'] == 0]
D_yes_df = data[data['Dyslexia'] == 1]

# Oversample 1-class and concat the DataFrames of both class
D_yes_df = D_yes_df.sample(count_D_no, replace = True)
data = pd.concat([D_no_df, D_yes_df], axis=0)

print('Random under-sampling Test:')
print(data.Dyslexia.value_counts())
# Out:
# Random under-sampling Test:
# 1    1247
# 0    1247
# Name: Dyslexia, dtype: int64

# %% [markdown]
# Se van a renombrar los índices para que no existan valores repetidos

# %%
data = data.reset_index(drop=True)
print("Duplicated data from Train Set: ",data.index.duplicated().sum())
# Out:
# Duplicated data from Train Set:  0

# %%
data.head()
# Out:
#    Gender  Nativelang  Otherlang  Age  Clicks1  Hits1  Misses1  Score1  \
# 0       0           1          0    7        6      6        0       6
# 1       1           1          0    7        7      7        0       7
# 2       1           1          0    7        6      6        0       6
# 3       0           1          0    7        5      5        0       5
# 4       0           1          0    7        8      6        2       8
#
#    Accuracy1  Missrate1  Clicks2  Hits2  Misses2  Score2  Accuracy2  \
# 0       1.00       0.00        5      4        1       5        0.8
# 1       1.00       0.00        7      7        0       7        1.0
# 2       1.00       0.00        7      7        0       7        1.0
# 3       1.00       0.00        5      4        1       5        0.8
# 4       0.75       0.25        4      4        0       4        1.0
#
#    Missrate2  Clicks3  Hits3  Misses3  Score3  Accuracy3  Missrate3  Clicks4  \
# 0        0.2        5      5        0       5   1.000000   0.000000        7
# 1        0.0        5      5        0       5   1.000000   0.000000        3
# 2        0.0        4      0        4       4   0.000000   1.000000        7
# 3        0.2        3      3        0       3   1.000000   0.000000        3
# 4        0.0        7      5        2       7   0.714286   0.285714        2
#
#    Hits4  Misses4  Score4  Accuracy4  Missrate4  Clicks5  Hits5  Misses5  \
# 0      0        7       7        0.0        1.0        5      5        0
# 1      3        0       3        1.0        0.0        4      4        0
# 2      0        7       7        0.0        1.0        3      1        2
# 3      3        0       3        1.0        0.0        2      2        0
# 4      2        0       2        1.0        0.0        3      0        3
#
#    Score5  Accuracy5  Missrate5  Clicks6  Hits6  Misses6  Score6  Accuracy6  \
# 0       5   1.000000   0.000000        4      3        1       4   0.750000
# 1       4   1.000000   0.000000        7      6        1       7   0.857143
# 2       3   0.333333   0.666667        4      3        1       4   0.750000
# 3       2   1.000000   0.000000        2      1        1       2   0.500000
# 4       3   0.000000   1.000000        2      0        2       2   0.000000
#
#    Missrate6  Clicks7  Hits7  Misses7  Score7  Accuracy7  Missrate7  Clicks8  \
# 0   0.250000        4      4        0       4   1.000000   0.000000        4
# 1   0.142857        5      5        0       5   1.000000   0.000000        2
# 2   0.250000        2      2        0       2   1.000000   0.000000        5
# 3   0.500000        3      3        0       3   1.000000   0.000000        1
# 4   1.000000        6      1        5       6   0.166667   0.833333        4
#
#    Hits8  Misses8  Score8  Accuracy8  Missrate8  Clicks9  Hits9  Misses9  \
# 0      4        0       4       1.00       0.00        2      2        0
# 1      1        1       2       0.50       0.50        2      2        0
# 2      3        2       5       0.60       0.40        6      1        5
# 3      1        0       1       1.00       0.00        2      2        0
# 4      3        1       4       0.75       0.25        5      2        3
#
#    Score9  Accuracy9  Missrate9  Clicks10  Hits10  Misses10  Score10  \
# 0       2   1.000000   0.000000         8       0         8        8
# 1       2   1.000000   0.000000         3       3         0        3
# 2       6   0.166667   0.833333         7       7         0        7
# 3       2   1.000000   0.000000         4       4         0        4
# 4       5   0.400000   0.600000         3       3         0        3
#
#    Accuracy10  Missrate10  Clicks11  Hits11  Misses11  Score11  Accuracy11  \
# 0         0.0         1.0         2       0         2        2    0.000000
# 1         1.0         0.0         3       2         1        3    0.666667
# 2         1.0         0.0         7       2         5        7    0.285714
# 3         1.0         0.0         2       2         0        2    1.000000
# 4         1.0         0.0         9       0         9        9    0.000000
#
#    Missrate11  Clicks12  Hits12  Misses12  Score12  Accuracy12  Missrate12  \
# 0    1.000000         3       0         3        3    0.000000    1.000000
# 1    0.333333         4       2         2        4    0.500000    0.500000
# 2    0.714286         3       2         1        3    0.666667    0.333333
# 3    0.000000         1       1         0        1    1.000000    0.000000
# 4    1.000000         6       4         2        6    0.666667    0.333333
#
#    Clicks13  Hits13  Misses13  Score13  Accuracy13  Missrate13  Clicks14  \
# 0       NaN     NaN       NaN      NaN         NaN         NaN         7
# 1       NaN     NaN       NaN      NaN         NaN         NaN         7
# 2       NaN     NaN       NaN      NaN         NaN         NaN         6
# 3       NaN     NaN       NaN      NaN         NaN         NaN         5
# 4       NaN     NaN       NaN      NaN         NaN         NaN         8
#
#    Hits14  Misses14  Score14  Accuracy14  Missrate14  Clicks15  Hits15  \
# 0       7         0        7         1.0         0.0         4       4
# 1       7         0        7         1.0         0.0         4       4
# 2       6         0        6         1.0         0.0         2       1
# 3       5         0        5         1.0         0.0         2       1
# 4       8         0        8         1.0         0.0         5       5
#
#    Misses15  Score15  Accuracy15  Missrate15  Clicks16  Hits16  Misses16  \
# 0         0        4         1.0         0.0         3       3         0
# 1         0        4         1.0         0.0         3       3         0
# 2         1        2         0.5         0.5         5       5         0
# 3         1        2         0.5         0.5         4       4         0
# 4         0        5         1.0         0.0         4       4         0
#
#    Score16  Accuracy16  Missrate16  Clicks17  Hits17  Misses17  Score17  \
# 0        3         1.0         0.0         5       5         0        5
# 1        3         1.0         0.0         3       3         0        3
# 2        5         1.0         0.0         4       4         0        4
# 3        4         1.0         0.0         3       3         0        3
# 4        4         1.0         0.0         5       5         0        5
#
#    Accuracy17  Missrate17  Clicks18  Hits18  Misses18  Score18  Accuracy18  \
# 0         1.0         0.0       NaN     NaN       NaN      NaN         NaN
# 1         1.0         0.0       NaN     NaN       NaN      NaN         NaN
# 2         1.0         0.0       NaN     NaN       NaN      NaN         NaN
# 3         1.0         0.0       NaN     NaN       NaN      NaN         NaN
# 4         1.0         0.0       NaN     NaN       NaN      NaN         NaN
#
#    Missrate18  Clicks19  Hits19  Misses19  Score19  Accuracy19  Missrate19  \
# 0         NaN       NaN     NaN       NaN      NaN         NaN         NaN
# 1         NaN       NaN     NaN       NaN      NaN         NaN         NaN
# 2         NaN       NaN     NaN       NaN      NaN         NaN         NaN
# 3         NaN       NaN     NaN       NaN      NaN         NaN         NaN
# 4         NaN       NaN     NaN       NaN      NaN         NaN         NaN
#
#    Clicks20  Hits20  Misses20  Score20  Accuracy20  Missrate20  Clicks21  \
# 0       NaN     NaN       NaN      NaN         NaN         NaN       NaN
# 1       NaN     NaN       NaN      NaN         NaN         NaN       NaN
# 2       NaN     NaN       NaN      NaN         NaN         NaN       NaN
# 3       NaN     NaN       NaN      NaN         NaN         NaN       NaN
# 4       NaN     NaN       NaN      NaN         NaN         NaN       NaN
#
#    Hits21  Misses21  Score21  Accuracy21  Missrate21  Clicks22  Hits22  \
# 0     NaN       NaN      NaN         NaN         NaN       1.0     1.0
# 1     NaN       NaN      NaN         NaN         NaN       2.0     0.0
# 2     NaN       NaN      NaN         NaN         NaN       5.0     1.0
# 3     NaN       NaN      NaN         NaN         NaN       3.0     0.0
# 4     NaN       NaN      NaN         NaN         NaN       6.0     1.0
#
#    Misses22  Score22  Accuracy22  Missrate22  Clicks23  Hits23  Misses23  \
# 0       0.0      1.0    1.000000    0.000000       4.0     4.0       0.0
# 1       2.0      2.0    0.000000    1.000000       4.0     0.0       4.0
# 2       4.0      5.0    0.200000    0.800000       4.0     4.0       0.0
# 3       3.0      3.0    0.000000    1.000000       3.0     2.0       1.0
# 4       5.0      6.0    0.166667    0.833333       4.0     3.0       1.0
#
#    Score23  Accuracy23  Missrate23  Clicks24  Hits24  Misses24  Score24  \
# 0      4.0    1.000000    0.000000       NaN     NaN       NaN      NaN
# 1      4.0    0.000000    1.000000       NaN     NaN       NaN      NaN
# 2      4.0    1.000000    0.000000       NaN     NaN       NaN      NaN
# 3      3.0    0.666667    0.333333       NaN     NaN       NaN      NaN
# 4      4.0    0.750000    0.250000       NaN     NaN       NaN      NaN
#
#    Accuracy24  Missrate24  Clicks25  Hits25  Misses25  Score25  Accuracy25  \
# 0         NaN         NaN       NaN     NaN       NaN      NaN         NaN
# 1         NaN         NaN       NaN     NaN       NaN      NaN         NaN
# 2         NaN         NaN       NaN     NaN       NaN      NaN         NaN
# 3         NaN         NaN       NaN     NaN       NaN      NaN         NaN
# 4         NaN         NaN       NaN     NaN       NaN      NaN         NaN
#
#    Missrate25  Clicks26  Hits26  Misses26  Score26  Accuracy26  Missrate26  \
# 0         NaN       NaN     NaN       NaN      NaN         NaN         NaN
# 1         NaN       NaN     NaN       NaN      NaN         NaN         NaN
# 2         NaN       NaN     NaN       NaN      NaN         NaN         NaN
# 3         NaN       NaN     NaN       NaN      NaN         NaN         NaN
# 4         NaN       NaN     NaN       NaN      NaN         NaN         NaN
#
#    Clicks27  Hits27  Misses27  Score27  Accuracy27  Missrate27  Clicks28  \
# 0       NaN     NaN       NaN      NaN         NaN         NaN       NaN
# 1       NaN     NaN       NaN      NaN         NaN         NaN       NaN
# 2       NaN     NaN       NaN      NaN         NaN         NaN       NaN
# 3       NaN     NaN       NaN      NaN         NaN         NaN       NaN
# 4       NaN     NaN       NaN      NaN         NaN         NaN       NaN
#
#    Hits28  Misses28  Score28  Accuracy28  Missrate28  Clicks29  Hits29  \
# 0     NaN       NaN      NaN         NaN         NaN       NaN     NaN
# 1     NaN       NaN      NaN         NaN         NaN       NaN     NaN
# 2     NaN       NaN      NaN         NaN         NaN       NaN     NaN
# 3     NaN       NaN      NaN         NaN         NaN       NaN     NaN
# 4     NaN       NaN      NaN         NaN         NaN       NaN     NaN
#
#    Misses29  Score29  Accuracy29  Missrate29  Clicks30  Hits30  Misses30  \
# 0       NaN      NaN         NaN         NaN      21.0     2.0       2.0
# 1       NaN      NaN         NaN         NaN      13.0     0.0       1.0
# 2       NaN      NaN         NaN         NaN      21.0     1.0       3.0
# 3       NaN      NaN         NaN         NaN      21.0     1.0       3.0
# 4       NaN      NaN         NaN         NaN      21.0     1.0       3.0
#
#    Score30  Accuracy30  Missrate30  Clicks31  Hits31  Misses31  Score31  \
# 0     21.0    0.095238    0.095238       NaN     NaN       NaN      NaN
# 1     13.0    0.000000    0.076923       NaN     NaN       NaN      NaN
# 2     21.0    0.047619    0.142857       NaN     NaN       NaN      NaN
# 3     21.0    0.047619    0.142857       NaN     NaN       NaN      NaN
# 4     21.0    0.047619    0.142857       NaN     NaN       NaN      NaN
#
#    Accuracy31  Missrate31  Clicks32  Hits32  Misses32  Score32  Accuracy32  \
# 0         NaN         NaN       NaN     NaN       NaN      NaN         NaN
# 1         NaN         NaN       NaN     NaN       NaN      NaN         NaN
# 2         NaN         NaN       NaN     NaN       NaN      NaN         NaN
# 3         NaN         NaN       NaN     NaN       NaN      NaN         NaN
# 4         NaN         NaN       NaN     NaN       NaN      NaN         NaN
#
#    Missrate32  Dyslexia
# 0         NaN         0
# 1         NaN         0
# 2         NaN         0
# 3         NaN         0
# 4         NaN         0

# %% [markdown]
# Tras transformar todos los valores del dataframe en numéricos, se va a asegurar que todos los valores sean tipo flotantes mediante la instrucción: `dataset.apply(lambda x: x.astype('float', errors='ignore'))` donde se aplica el cambio de *int* a *flot* mediante la función `astype()` dentro de una función *lambda* que recorre cada columna, accediendo a su contenido y modificándolo.

# %%
data = data.apply(lambda x: x.astype('float', errors='ignore'))

# %% [markdown]
# Una vez se haya transformado el tipo de valor con el que se está trabajando se va a comprobar que los dataframes utilizados solo contienen valores del tipo *float64*:

# %%
#check the data type of each column
for col in data.columns:
    if data[col].dtypes != "float64":
        print("Column {} is not a float, it is {}".format(col, data[col].dtypes))

# %% [markdown]
# Una vez exportados los datos se va a comporbar si hay valores nulos mediante la función `[col for col in test_df.columns if train_df[col].isnull().any()]`.
# - Mediante el bucle `for col in` se van a recorrer todas las columna y acceder a sus valores.
# - Mediante el condicional `if train_df[col].isnull().any()`se va a comprobar si alguno de los datos de la columna que se está analizando es nulo o no.
#
# En caso de que se encuentre un valor nulo, el atributo de salida `col` tomará el valor de dicha columna y se añadirá a una lista (función entre `[ ]`).
#
# Se obtiene que el dataset correspondiente a los datos *train* no contienen ningún valor nulo, sin mebargo, los datos del dataset *test* sí. Cabe destacar que las columnas correspondientes a la *Question 29* ( 'Clicks29', 'Hits29', 'Misses29', 'Score29', 'Accuracy29', 'Missrate29') no contienen ningún valor. Es decir, dichas columnas solo están compuestas por valores nulos, por lo que no aportan información.

# %%
data.describe(include = [np.number])
data.isnull().values.any()
data_null_values = data.isna().sum().sum()
data_null_col = [col for col in data.columns if data[col].isnull().any()]
#data_null_col

# %% [markdown]
# ### Handle null values

# %% [markdown]
# Como se ha mencionado anteriormente, en el dataset correspondiente a *test* existen multitud de valores nulos, los cuales deben ser transformados para poder diseñar el modelo en Machine Learning adecuadamente. Para ello se van a emplear distintas técticas:
# 1.  **Eliminación de las columnas con valores nulos**: si una fila presenta valores no numéricos, mediante la función `drop()`, se va a prescindir de ella y no se tendrá encuentra en el diseño del modelo.
# 2. **Sustitución por cero**: si una columna presenta valores no numéricos, se sustituira el valor *Nan* por *0* mediante la función `fillna(0)`. Solo se modificará el dataset *test*, ya que no se está eliminando ninguna fila.
# 3. **Sustitución por la media y la mediana**: si una columna presenta valores no numéricos, se calculará la media y la mediana de dicha columna mediante las funciones `mean()` y `median()`, respectivamente, se sustituirán los valores *Nan* de cada columna. En caso de que una columna no presente ningún valor numérico se eliminará, tanto en el dataset *test* como *train*, de froma análoga.
#
# Como se ha observado en la sección anterior, en el dataset que se va a usar para testear el modelo las columnas correspondientes a la cuestión 29 no presentan valores numéricos. Por ello, se ha decidido eliminarlas y no tenerlas en cuenta en el estudio, tanto del dataset *train* como *test*.

# %%
#columns to be removed
column29 = ['Clicks29', 'Hits29', 'Misses29', 'Score29', 'Accuracy29', 'Missrate29']
#drop Q29
data = data.drop(column29, axis=1)

# %%
data.head()
# Out:
#    Gender  Nativelang  Otherlang  Age  Clicks1  Hits1  Misses1  Score1  \
# 0     0.0         1.0        0.0  7.0      6.0    6.0      0.0     6.0
# 1     1.0         1.0        0.0  7.0      7.0    7.0      0.0     7.0
# 2     1.0         1.0        0.0  7.0      6.0    6.0      0.0     6.0
# 3     0.0         1.0        0.0  7.0      5.0    5.0      0.0     5.0
# 4     0.0         1.0        0.0  7.0      8.0    6.0      2.0     8.0
#
#    Accuracy1  Missrate1  Clicks2  Hits2  Misses2  Score2  Accuracy2  \
# 0       1.00       0.00      5.0    4.0      1.0     5.0        0.8
# 1       1.00       0.00      7.0    7.0      0.0     7.0        1.0
# 2       1.00       0.00      7.0    7.0      0.0     7.0        1.0
# 3       1.00       0.00      5.0    4.0      1.0     5.0        0.8
# 4       0.75       0.25      4.0    4.0      0.0     4.0        1.0
#
#    Missrate2  Clicks3  Hits3  Misses3  Score3  Accuracy3  Missrate3  Clicks4  \
# 0        0.2      5.0    5.0      0.0     5.0   1.000000   0.000000      7.0
# 1        0.0      5.0    5.0      0.0     5.0   1.000000   0.000000      3.0
# 2        0.0      4.0    0.0      4.0     4.0   0.000000   1.000000      7.0
# 3        0.2      3.0    3.0      0.0     3.0   1.000000   0.000000      3.0
# 4        0.0      7.0    5.0      2.0     7.0   0.714286   0.285714      2.0
#
#    Hits4  Misses4  Score4  Accuracy4  Missrate4  Clicks5  Hits5  Misses5  \
# 0    0.0      7.0     7.0        0.0        1.0      5.0    5.0      0.0
# 1    3.0      0.0     3.0        1.0        0.0      4.0    4.0      0.0
# 2    0.0      7.0     7.0        0.0        1.0      3.0    1.0      2.0
# 3    3.0      0.0     3.0        1.0        0.0      2.0    2.0      0.0
# 4    2.0      0.0     2.0        1.0        0.0      3.0    0.0      3.0
#
#    Score5  Accuracy5  Missrate5  Clicks6  Hits6  Misses6  Score6  Accuracy6  \
# 0     5.0   1.000000   0.000000      4.0    3.0      1.0     4.0   0.750000
# 1     4.0   1.000000   0.000000      7.0    6.0      1.0     7.0   0.857143
# 2     3.0   0.333333   0.666667      4.0    3.0      1.0     4.0   0.750000
# 3     2.0   1.000000   0.000000      2.0    1.0      1.0     2.0   0.500000
# 4     3.0   0.000000   1.000000      2.0    0.0      2.0     2.0   0.000000
#
#    Missrate6  Clicks7  Hits7  Misses7  Score7  Accuracy7  Missrate7  Clicks8  \
# 0   0.250000      4.0    4.0      0.0     4.0   1.000000   0.000000      4.0
# 1   0.142857      5.0    5.0      0.0     5.0   1.000000   0.000000      2.0
# 2   0.250000      2.0    2.0      0.0     2.0   1.000000   0.000000      5.0
# 3   0.500000      3.0    3.0      0.0     3.0   1.000000   0.000000      1.0
# 4   1.000000      6.0    1.0      5.0     6.0   0.166667   0.833333      4.0
#
#    Hits8  Misses8  Score8  Accuracy8  Missrate8  Clicks9  Hits9  Misses9  \
# 0    4.0      0.0     4.0       1.00       0.00      2.0    2.0      0.0
# 1    1.0      1.0     2.0       0.50       0.50      2.0    2.0      0.0
# 2    3.0      2.0     5.0       0.60       0.40      6.0    1.0      5.0
# 3    1.0      0.0     1.0       1.00       0.00      2.0    2.0      0.0
# 4    3.0      1.0     4.0       0.75       0.25      5.0    2.0      3.0
#
#    Score9  Accuracy9  Missrate9  Clicks10  Hits10  Misses10  Score10  \
# 0     2.0   1.000000   0.000000       8.0     0.0       8.0      8.0
# 1     2.0   1.000000   0.000000       3.0     3.0       0.0      3.0
# 2     6.0   0.166667   0.833333       7.0     7.0       0.0      7.0
# 3     2.0   1.000000   0.000000       4.0     4.0       0.0      4.0
# 4     5.0   0.400000   0.600000       3.0     3.0       0.0      3.0
#
#    Accuracy10  Missrate10  Clicks11  Hits11  Misses11  Score11  Accuracy11  \
# 0         0.0         1.0       2.0     0.0       2.0      2.0    0.000000
# 1         1.0         0.0       3.0     2.0       1.0      3.0    0.666667
# 2         1.0         0.0       7.0     2.0       5.0      7.0    0.285714
# 3         1.0         0.0       2.0     2.0       0.0      2.0    1.000000
# 4         1.0         0.0       9.0     0.0       9.0      9.0    0.000000
#
#    Missrate11  Clicks12  Hits12  Misses12  Score12  Accuracy12  Missrate12  \
# 0    1.000000       3.0     0.0       3.0      3.0    0.000000    1.000000
# 1    0.333333       4.0     2.0       2.0      4.0    0.500000    0.500000
# 2    0.714286       3.0     2.0       1.0      3.0    0.666667    0.333333
# 3    0.000000       1.0     1.0       0.0      1.0    1.000000    0.000000
# 4    1.000000       6.0     4.0       2.0      6.0    0.666667    0.333333
#
#    Clicks13  Hits13  Misses13  Score13  Accuracy13  Missrate13  Clicks14  \
# 0       NaN     NaN       NaN      NaN         NaN         NaN       7.0
# 1       NaN     NaN       NaN      NaN         NaN         NaN       7.0
# 2       NaN     NaN       NaN      NaN         NaN         NaN       6.0
# 3       NaN     NaN       NaN      NaN         NaN         NaN       5.0
# 4       NaN     NaN       NaN      NaN         NaN         NaN       8.0
#
#    Hits14  Misses14  Score14  Accuracy14  Missrate14  Clicks15  Hits15  \
# 0     7.0       0.0      7.0         1.0         0.0       4.0     4.0
# 1     7.0       0.0      7.0         1.0         0.0       4.0     4.0
# 2     6.0       0.0      6.0         1.0         0.0       2.0     1.0
# 3     5.0       0.0      5.0         1.0         0.0       2.0     1.0
# 4     8.0       0.0      8.0         1.0         0.0       5.0     5.0
#
#    Misses15  Score15  Accuracy15  Missrate15  Clicks16  Hits16  Misses16  \
# 0       0.0      4.0         1.0         0.0       3.0     3.0       0.0
# 1       0.0      4.0         1.0         0.0       3.0     3.0       0.0
# 2       1.0      2.0         0.5         0.5       5.0     5.0       0.0
# 3       1.0      2.0         0.5         0.5       4.0     4.0       0.0
# 4       0.0      5.0         1.0         0.0       4.0     4.0       0.0
#
#    Score16  Accuracy16  Missrate16  Clicks17  Hits17  Misses17  Score17  \
# 0      3.0         1.0         0.0       5.0     5.0       0.0      5.0
# 1      3.0         1.0         0.0       3.0     3.0       0.0      3.0
# 2      5.0         1.0         0.0       4.0     4.0       0.0      4.0
# 3      4.0         1.0         0.0       3.0     3.0       0.0      3.0
# 4      4.0         1.0         0.0       5.0     5.0       0.0      5.0
#
#    Accuracy17  Missrate17  Clicks18  Hits18  Misses18  Score18  Accuracy18  \
# 0         1.0         0.0       NaN     NaN       NaN      NaN         NaN
# 1         1.0         0.0       NaN     NaN       NaN      NaN         NaN
# 2         1.0         0.0       NaN     NaN       NaN      NaN         NaN
# 3         1.0         0.0       NaN     NaN       NaN      NaN         NaN
# 4         1.0         0.0       NaN     NaN       NaN      NaN         NaN
#
#    Missrate18  Clicks19  Hits19  Misses19  Score19  Accuracy19  Missrate19  \
# 0         NaN       NaN     NaN       NaN      NaN         NaN         NaN
# 1         NaN       NaN     NaN       NaN      NaN         NaN         NaN
# 2         NaN       NaN     NaN       NaN      NaN         NaN         NaN
# 3         NaN       NaN     NaN       NaN      NaN         NaN         NaN
# 4         NaN       NaN     NaN       NaN      NaN         NaN         NaN
#
#    Clicks20  Hits20  Misses20  Score20  Accuracy20  Missrate20  Clicks21  \
# 0       NaN     NaN       NaN      NaN         NaN         NaN       NaN
# 1       NaN     NaN       NaN      NaN         NaN         NaN       NaN
# 2       NaN     NaN       NaN      NaN         NaN         NaN       NaN
# 3       NaN     NaN       NaN      NaN         NaN         NaN       NaN
# 4       NaN     NaN       NaN      NaN         NaN         NaN       NaN
#
#    Hits21  Misses21  Score21  Accuracy21  Missrate21  Clicks22  Hits22  \
# 0     NaN       NaN      NaN         NaN         NaN       1.0     1.0
# 1     NaN       NaN      NaN         NaN         NaN       2.0     0.0
# 2     NaN       NaN      NaN         NaN         NaN       5.0     1.0
# 3     NaN       NaN      NaN         NaN         NaN       3.0     0.0
# 4     NaN       NaN      NaN         NaN         NaN       6.0     1.0
#
#    Misses22  Score22  Accuracy22  Missrate22  Clicks23  Hits23  Misses23  \
# 0       0.0      1.0    1.000000    0.000000       4.0     4.0       0.0
# 1       2.0      2.0    0.000000    1.000000       4.0     0.0       4.0
# 2       4.0      5.0    0.200000    0.800000       4.0     4.0       0.0
# 3       3.0      3.0    0.000000    1.000000       3.0     2.0       1.0
# 4       5.0      6.0    0.166667    0.833333       4.0     3.0       1.0
#
#    Score23  Accuracy23  Missrate23  Clicks24  Hits24  Misses24  Score24  \
# 0      4.0    1.000000    0.000000       NaN     NaN       NaN      NaN
# 1      4.0    0.000000    1.000000       NaN     NaN       NaN      NaN
# 2      4.0    1.000000    0.000000       NaN     NaN       NaN      NaN
# 3      3.0    0.666667    0.333333       NaN     NaN       NaN      NaN
# 4      4.0    0.750000    0.250000       NaN     NaN       NaN      NaN
#
#    Accuracy24  Missrate24  Clicks25  Hits25  Misses25  Score25  Accuracy25  \
# 0         NaN         NaN       NaN     NaN       NaN      NaN         NaN
# 1         NaN         NaN       NaN     NaN       NaN      NaN         NaN
# 2         NaN         NaN       NaN     NaN       NaN      NaN         NaN
# 3         NaN         NaN       NaN     NaN       NaN      NaN         NaN
# 4         NaN         NaN       NaN     NaN       NaN      NaN         NaN
#
#    Missrate25  Clicks26  Hits26  Misses26  Score26  Accuracy26  Missrate26  \
# 0         NaN       NaN     NaN       NaN      NaN         NaN         NaN
# 1         NaN       NaN     NaN       NaN      NaN         NaN         NaN
# 2         NaN       NaN     NaN       NaN      NaN         NaN         NaN
# 3         NaN       NaN     NaN       NaN      NaN         NaN         NaN
# 4         NaN       NaN     NaN       NaN      NaN         NaN         NaN
#
#    Clicks27  Hits27  Misses27  Score27  Accuracy27  Missrate27  Clicks28  \
# 0       NaN     NaN       NaN      NaN         NaN         NaN       NaN
# 1       NaN     NaN       NaN      NaN         NaN         NaN       NaN
# 2       NaN     NaN       NaN      NaN         NaN         NaN       NaN
# 3       NaN     NaN       NaN      NaN         NaN         NaN       NaN
# 4       NaN     NaN       NaN      NaN         NaN         NaN       NaN
#
#    Hits28  Misses28  Score28  Accuracy28  Missrate28  Clicks30  Hits30  \
# 0     NaN       NaN      NaN         NaN         NaN      21.0     2.0
# 1     NaN       NaN      NaN         NaN         NaN      13.0     0.0
# 2     NaN       NaN      NaN         NaN         NaN      21.0     1.0
# 3     NaN       NaN      NaN         NaN         NaN      21.0     1.0
# 4     NaN       NaN      NaN         NaN         NaN      21.0     1.0
#
#    Misses30  Score30  Accuracy30  Missrate30  Clicks31  Hits31  Misses31  \
# 0       2.0     21.0    0.095238    0.095238       NaN     NaN       NaN
# 1       1.0     13.0    0.000000    0.076923       NaN     NaN       NaN
# 2       3.0     21.0    0.047619    0.142857       NaN     NaN       NaN
# 3       3.0     21.0    0.047619    0.142857       NaN     NaN       NaN
# 4       3.0     21.0    0.047619    0.142857       NaN     NaN       NaN
#
#    Score31  Accuracy31  Missrate31  Clicks32  Hits32  Misses32  Score32  \
# 0      NaN         NaN         NaN       NaN     NaN       NaN      NaN
# 1      NaN         NaN         NaN       NaN     NaN       NaN      NaN
# 2      NaN         NaN         NaN       NaN     NaN       NaN      NaN
# 3      NaN         NaN         NaN       NaN     NaN       NaN      NaN
# 4      NaN         NaN         NaN       NaN     NaN       NaN      NaN
#
#    Accuracy32  Missrate32  Dyslexia
# 0         NaN         NaN       0.0
# 1         NaN         NaN       0.0
# 2         NaN         NaN       0.0
# 3         NaN         NaN       0.0
# 4         NaN         NaN       0.0

# %% [markdown]
# Antes de proceder con el ajuste los valores nulos, para no influir erróneamente en el cálculo de la media y la mediana, se va a prescindir de todos los valores mayores a uno en las columnas *Accuracy* y *Missrate*. Los valores mencionados representan porcentajes, por lo que no pueden superar la unidad, sin embargo, si se estudia en detalle cada variable existen valores que no cumplen este requisito dando lugar a error si no se corrige.

# %%
def remove_outliers_manually(df):
    print("Old Shape: ", df.shape)
    
    #Accuracy and Missrate
    for i in range(int(df.shape[1]/6)):
        col_acc_rate = df.columns[8+6*i:10+6*i]
        for j in col_acc_rate:
            df.drop(df[df[j] > 1].index, inplace=True)
    print("New Shape: ", df.shape)

# %%
remove_outliers_manually(data)
# Out:
# Old Shape:  (2494, 191)
# New Shape:  (1777, 191)

# %%
##1 DROP
drop_df = data.dropna()

##2 ZEROS
zero_df = data.fillna(0)

##3 MEAN & MEDIAN
#3.1 MEAN
#Mean Fill
mean_df = data.fillna(data.mean())

#3.2 MEDIAN
#Median Fill
median_df = data.fillna(data.median())

# %% [markdown]
# Tras realizar las modificaciones convenientes, se va a comprobar que ningún dataset contiene valores nulos:

# %% [markdown]
# #### 1. Drop

# %%
#1 DROP
drop_df.head()
null_col_drop = [col for col in drop_df.columns if drop_df[col].isnull().any()]
null_col_drop
# Out:
# []

# %% [markdown]
# #### 2. Zero

# %%
#2 ZEROS
zero_df.head()
null_col_zero = [col for col in zero_df.columns if zero_df[col].isnull().any()]
null_col_zero
# Out:
# []

# %% [markdown]
# #### 3.1. Mean

# %%
#3.1 MEAN
mean_df.head()
null_col_mean = [col for col in mean_df.columns if mean_df[col].isnull().any()]
null_col_mean
# Out:
# []

# %% [markdown]
# #### 3.2. Median

# %%
#3.2 MEDIAN
median_df.head()
null_col_median = [col for col in median_df.columns if median_df[col].isnull().any()]
null_col_median
# Out:
# []

# %% [markdown]
# ### Handling outliers

# %% [markdown]
# A continuación, se va a proceder con la eliminación de los outliers, es decir, se va a prescindir de aquellos valores que se consideren anómalos. Para ello se van a emplear dos funciones *.describe()* y *sns.distplot(col)*. La primera  se utiliza para representar la distribución de los datos en un gráfico. Va a permitir visualizar la forma en que los datos están distribuidos en los datasets disponibles. A simple vista, se puede identificar como hay valores máximos que están muy alejados del percentil 75, por lo que se puede intuir que se trata de un outlier.
#
# A su vez, la función `countplot` es útil para identificar cuantos valores positivos y negativos hay de dislexia. Se va a representar visualmente, permitiendo comparar si la muestra que se está usando es representativa de la población.

# %%
data.describe()
# Out:
#             Gender   Nativelang    Otherlang          Age      Clicks1  \
# count  1777.000000  1777.000000  1777.000000  1777.000000  1777.000000
# mean      0.505909     0.968486     0.182330     9.838492     7.293191
# std       0.500106     0.174751     0.386225     2.322123     3.516391
# min       0.000000     0.000000     0.000000     7.000000     0.000000
# 25%       0.000000     1.000000     0.000000     8.000000     5.000000
# 50%       1.000000     1.000000     0.000000     9.000000     7.000000
# 75%       1.000000     1.000000     0.000000    11.000000    10.000000
# max       1.000000     1.000000     1.000000    17.000000    50.000000
#
#              Hits1      Misses1       Score1    Accuracy1    Missrate1  \
# count  1777.000000  1777.000000  1777.000000  1777.000000  1777.000000
# mean      7.045020     0.248171     7.293191     0.937556     0.051752
# std       3.433604     1.196268     3.516391     0.211811     0.188115
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       5.000000     0.000000     5.000000     1.000000     0.000000
# 50%       7.000000     0.000000     7.000000     1.000000     0.000000
# 75%      10.000000     0.000000    10.000000     1.000000     0.000000
# max      20.000000    30.000000    50.000000     1.000000     1.000000
#
#            Clicks2        Hits2      Misses2       Score2    Accuracy2  \
# count  1777.000000  1777.000000  1777.000000  1777.000000  1777.000000
# mean      6.830613     6.507597     0.323016     6.830613     0.938644
# std       2.870126     2.796409     1.467476     2.870126     0.191546
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       5.000000     5.000000     0.000000     5.000000     1.000000
# 50%       7.000000     7.000000     0.000000     7.000000     1.000000
# 75%       9.000000     9.000000     0.000000     9.000000     1.000000
# max      41.000000    14.000000    33.000000    41.000000     1.000000
#
#          Missrate2      Clicks3        Hits3      Misses3       Score3  \
# count  1777.000000  1777.000000  1777.000000  1777.000000  1777.000000
# mean      0.059105     5.657850     5.230163     0.427687     5.657850
# std       0.186303     2.910448     2.265694     2.386259     2.910448
# min       0.000000     1.000000     0.000000     0.000000     1.000000
# 25%       0.000000     4.000000     4.000000     0.000000     4.000000
# 50%       0.000000     6.000000     5.000000     0.000000     6.000000
# 75%       0.000000     7.000000     7.000000     0.000000     7.000000
# max       1.000000    75.000000    12.000000    69.000000    75.000000
#
#          Accuracy3    Missrate3      Clicks4        Hits4      Misses4  \
# count  1777.000000  1777.000000  1777.000000  1777.000000  1777.000000
# mean      0.915566     0.084434     3.543613     2.296005     1.247608
# std       0.239412     0.239412     2.609415     1.734049     2.856265
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     1.000000     0.000000
# 50%       1.000000     0.000000     3.000000     2.000000     0.000000
# 75%       1.000000     0.000000     5.000000     3.000000     1.000000
# max       1.000000     1.000000    65.000000     9.000000    61.000000
#
#             Score4    Accuracy4    Missrate4      Clicks5        Hits5  \
# count  1777.000000  1777.000000  1777.000000  1777.000000  1777.000000
# mean      3.543613     0.734715     0.261909     4.496905     4.005627
# std       2.609415     0.406702     0.404733     2.285658     2.063183
# min       0.000000     0.000000     0.000000     1.000000     0.000000
# 25%       2.000000     0.500000     0.000000     3.000000     3.000000
# 50%       3.000000     1.000000     0.000000     4.000000     4.000000
# 75%       5.000000     1.000000     0.500000     6.000000     6.000000
# max      65.000000     1.000000     1.000000    43.000000    11.000000
#
#            Misses5       Score5    Accuracy5    Missrate5      Clicks6  \
# count  1777.000000  1777.000000  1777.000000  1777.000000  1777.000000
# mean      0.491277     4.496905     0.861145     0.138855     3.985369
# std       1.649480     2.285658     0.287548     0.287548     2.868909
# min       0.000000     1.000000     0.000000     0.000000     0.000000
# 25%       0.000000     3.000000     0.857143     0.000000     3.000000
# 50%       0.000000     4.000000     1.000000     0.000000     4.000000
# 75%       1.000000     6.000000     1.000000     0.142857     5.000000
# max      34.000000    43.000000     1.000000     1.000000    61.000000
#
#              Hits6      Misses6       Score6    Accuracy6    Missrate6  \
# count  1777.000000  1777.000000  1777.000000  1777.000000  1777.000000
# mean      2.768711     1.216657     3.985369     0.692594     0.305718
# std       1.749186     2.541944     2.868909     0.349425     0.348488
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     3.000000     0.500000     0.000000
# 50%       3.000000     1.000000     4.000000     0.800000     0.200000
# 75%       4.000000     2.000000     5.000000     1.000000     0.500000
# max      11.000000    53.000000    61.000000     1.000000     1.000000
#
#            Clicks7        Hits7      Misses7       Score7    Accuracy7  \
# count  1777.000000  1777.000000  1777.000000  1777.000000  1777.000000
# mean      4.624086     4.180642     0.443444     4.624086     0.904002
# std       4.431212     3.655877     2.435724     4.431212     0.260629
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       3.000000     3.000000     0.000000     3.000000     1.000000
# 50%       4.000000     4.000000     0.000000     4.000000     1.000000
# 75%       6.000000     5.000000     0.000000     6.000000     1.000000
# max      64.000000    47.000000    58.000000    64.000000     1.000000
#
#          Missrate7      Clicks8        Hits8      Misses8       Score8  \
# count  1777.000000  1777.000000  1777.000000  1777.000000  1777.000000
# mean      0.085868     4.194710     3.557681     0.637029     4.194710
# std       0.244204     2.859179     1.750537     2.411833     2.859179
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     3.000000     2.000000     0.000000     3.000000
# 50%       0.000000     4.000000     4.000000     0.000000     4.000000
# 75%       0.000000     5.000000     5.000000     1.000000     5.000000
# max       1.000000    69.000000     9.000000    60.000000    69.000000
#
#          Accuracy8    Missrate8      Clicks9        Hits9      Misses9  \
# count  1777.000000  1777.000000  1777.000000  1777.000000  1777.000000
# mean      0.869984     0.129453     3.068655     1.902645     1.166010
# std       0.237607     0.236728     3.117051     1.324611     2.969252
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.800000     0.000000     2.000000     1.000000     0.000000
# 50%       1.000000     0.000000     3.000000     2.000000     0.000000
# 75%       1.000000     0.200000     4.000000     3.000000     2.000000
# max       1.000000     1.000000    64.000000    10.000000    58.000000
#
#             Score9    Accuracy9    Missrate9     Clicks10       Hits10  \
# count  1777.000000  1777.000000  1777.000000  1777.000000  1777.000000
# mean      3.068655     0.691754     0.306558     6.110298     5.123241
# std       3.117051     0.383048     0.382198     3.801996     2.650855
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.500000     0.000000     4.000000     3.000000
# 50%       3.000000     1.000000     0.000000     6.000000     5.000000
# 75%       4.000000     1.000000     0.500000     7.000000     7.000000
# max      64.000000     1.000000     1.000000    61.000000    17.000000
#
#           Misses10      Score10   Accuracy10   Missrate10     Clicks11  \
# count  1777.000000  1777.000000  1777.000000  1777.000000  1777.000000
# mean      0.987057     6.110298     0.847096     0.151216     3.924029
# std       3.299323     3.801996     0.300677     0.298716     3.374582
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     4.000000     0.833333     0.000000     2.000000
# 50%       0.000000     6.000000     1.000000     0.000000     4.000000
# 75%       1.000000     7.000000     1.000000     0.166667     5.000000
# max      44.000000    61.000000     1.000000     1.000000    63.000000
#
#             Hits11     Misses11      Score11   Accuracy11   Missrate11  \
# count  1777.000000  1777.000000  1777.000000  1777.000000  1777.000000
# mean      2.942037     0.981992     3.924029     0.752247     0.244940
# std       1.847056     2.847615     3.374582     0.320458     0.318222
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     2.000000     0.600000     0.000000
# 50%       3.000000     0.000000     4.000000     0.857143     0.000000
# 75%       4.000000     1.000000     5.000000     1.000000     0.400000
# max       9.000000    54.000000    63.000000     1.000000     1.000000
#
#           Clicks12       Hits12     Misses12      Score12   Accuracy12  \
# count  1777.000000  1777.000000  1777.000000  1777.000000  1777.000000
# mean      4.359595     3.115926     1.243669     4.359595     0.783346
# std       4.552077     1.717379     4.188915     4.552077     0.292695
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       3.000000     2.000000     0.000000     3.000000     0.666667
# 50%       4.000000     3.000000     0.000000     4.000000     1.000000
# 75%       5.000000     4.000000     1.000000     5.000000     1.000000
# max      58.000000    12.000000    46.000000    58.000000     1.000000
#
#         Missrate12     Clicks13       Hits13     Misses13      Score13  \
# count  1777.000000  1146.000000  1146.000000  1146.000000  1146.000000
# mean      0.212715     5.309773     3.468586     1.841187     5.309773
# std       0.288828     6.109841     1.750700     5.627063     6.109841
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     3.000000     2.000000     0.000000     3.000000
# 50%       0.000000     4.000000     3.000000     1.000000     4.000000
# 75%       0.333333     6.000000     5.000000     2.000000     6.000000
# max       1.000000    60.000000    10.000000    56.000000    60.000000
#
#         Accuracy13   Missrate13     Clicks14       Hits14     Misses14  \
# count  1146.000000  1146.000000  1777.000000  1777.000000  1777.000000
# mean      0.741042     0.258085     7.060777     6.752392     0.308385
# std       0.273340     0.272567     2.653554     2.407881     1.824354
# min       0.000000     0.000000     1.000000     0.000000     0.000000
# 25%       0.666667     0.000000     5.000000     5.000000     0.000000
# 50%       0.800000     0.200000     7.000000     7.000000     0.000000
# 75%       1.000000     0.333333     9.000000     9.000000     0.000000
# max       1.000000     1.000000    43.000000    13.000000    39.000000
#
#            Score14   Accuracy14   Missrate14     Clicks15       Hits15  \
# count  1777.000000  1777.000000  1777.000000  1777.000000  1777.000000
# mean      7.060777     0.959380     0.040620     4.094541     3.707372
# std       2.653554     0.136176     0.136176     3.055614     2.064805
# min       1.000000     0.000000     0.000000     0.000000     0.000000
# 25%       5.000000     1.000000     0.000000     3.000000     2.000000
# 50%       7.000000     1.000000     0.000000     4.000000     4.000000
# 75%       9.000000     1.000000     0.000000     5.000000     5.000000
# max      43.000000     1.000000     1.000000    68.000000    10.000000
#
#           Misses15      Score15   Accuracy15   Missrate15     Clicks16  \
# count  1777.000000  1777.000000  1777.000000  1777.000000  1777.000000
# mean      0.387169     4.094541     0.907156     0.077087     4.383793
# std       2.640386     3.055614     0.253687     0.226430     2.619041
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     3.000000     1.000000     0.000000     3.000000
# 50%       0.000000     4.000000     1.000000     0.000000     4.000000
# 75%       0.000000     5.000000     1.000000     0.000000     5.000000
# max      68.000000    68.000000     1.000000     1.000000    50.000000
#
#             Hits16     Misses16      Score16   Accuracy16   Missrate16  \
# count  1777.000000  1777.000000  1777.000000  1777.000000  1777.000000
# mean      4.135059     0.248734     4.383793     0.962557     0.036317
# std       1.590652     2.257627     2.619041     0.121130     0.116746
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       3.000000     0.000000     3.000000     1.000000     0.000000
# 50%       4.000000     0.000000     4.000000     1.000000     0.000000
# 75%       5.000000     0.000000     5.000000     1.000000     0.000000
# max      10.000000    49.000000    50.000000     1.000000     1.000000
#
#           Clicks17       Hits17     Misses17      Score17   Accuracy17  \
# count  1777.000000  1777.000000  1777.000000  1777.000000  1777.000000
# mean      4.343838     3.652786     0.691052     4.343838     0.918774
# std       4.420909     1.735423     4.466428     4.420909     0.200999
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       3.000000     2.000000     0.000000     3.000000     1.000000
# 50%       4.000000     4.000000     0.000000     4.000000     1.000000
# 75%       5.000000     5.000000     0.000000     5.000000     1.000000
# max      46.000000    10.000000    46.000000    46.000000     1.000000
#
#         Missrate17     Clicks18       Hits18     Misses18      Score18  \
# count  1777.000000  1146.000000  1146.000000  1146.000000  1146.000000
# mean      0.076161     4.631763     3.074171     1.557592     4.631763
# std       0.190080     4.546183     1.924491     4.071704     4.546183
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000     3.000000     2.000000     0.000000     3.000000
# 50%       0.000000     4.000000     3.000000     1.000000     4.000000
# 75%       0.000000     5.000000     4.000000     2.000000     5.000000
# max       1.000000    56.000000     9.000000    53.000000    56.000000
#
#         Accuracy18   Missrate18     Clicks19       Hits19     Misses19  \
# count  1146.000000  1146.000000  1146.000000  1146.000000  1146.000000
# mean      0.702243     0.292522     4.649215     2.555846     2.068935
# std       0.355344     0.352310     4.617130     1.623228     4.313233
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.500000     0.000000     3.000000     1.000000     0.000000
# 50%       0.800000     0.200000     4.000000     2.000000     1.000000
# 75%       1.000000     0.500000     5.000000     4.000000     2.000000
# max       1.000000     1.000000    54.000000     9.000000    46.000000
#
#            Score19   Accuracy19   Missrate19     Clicks20       Hits20  \
# count  1146.000000  1146.000000  1146.000000  1144.000000  1144.000000
# mean      4.649215     0.624275     0.372474     4.148601     1.188811
# std       4.617130     0.318102     0.316706     4.310229     1.189491
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       3.000000     0.400000     0.000000     2.000000     0.000000
# 50%       4.000000     0.666667     0.333333     3.000000     1.000000
# 75%       5.000000     1.000000     0.600000     5.000000     2.000000
# max      54.000000     1.000000     1.000000    58.000000     8.000000
#
#          Misses20      Score20   Accuracy20   Missrate20    Clicks21  \
# count  1144.00000  1144.000000  1146.000000  1146.000000  432.000000
# mean      2.95979     4.148601     0.341321     0.655188    4.402778
# std       4.00264     4.310229     0.325979     0.327657    7.579114
# min       0.00000     0.000000     0.000000     0.000000    0.000000
# 25%       1.00000     2.000000     0.000000     0.500000    2.000000
# 50%       2.00000     3.000000     0.333333     0.666667    3.000000
# 75%       3.00000     5.000000     0.500000     1.000000    4.000000
# max      51.00000    58.000000     1.000000     1.000000   53.000000
#
#            Hits21    Misses21     Score21  Accuracy21  Missrate21  \
# count  432.000000  432.000000  432.000000  432.000000  432.000000
# mean     1.127315    3.275463    4.402778    0.371283    0.624087
# std      1.185760    7.062568    7.579114    0.370006    0.371588
# min      0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000    2.000000    0.000000    0.333333
# 50%      1.000000    2.000000    3.000000    0.333333    0.666667
# 75%      2.000000    3.000000    4.000000    0.666667    1.000000
# max      6.000000   48.000000   53.000000    1.000000    1.000000
#
#           Clicks22       Hits22     Misses22      Score22   Accuracy22  \
# count  1775.000000  1775.000000  1775.000000  1775.000000  1777.000000
# mean      4.953239     3.260845     1.692394     4.953239     0.669689
# std       5.859166     2.492178     4.445590     5.859166     0.300502
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       3.000000     2.000000     0.000000     3.000000     0.500000
# 50%       4.000000     3.000000     1.000000     4.000000     0.750000
# 75%       5.000000     4.000000     2.000000     5.000000     1.000000
# max     144.000000    37.000000   107.000000   144.000000     1.000000
#
#         Missrate22     Clicks23       Hits23     Misses23      Score23  \
# count  1777.000000  1775.000000  1775.000000  1775.000000  1775.000000
# mean      0.326372     5.587606     3.715493     1.872113     5.587606
# std       0.298242     5.594838     2.358429     4.568159     5.594838
# min       0.000000     1.000000     0.000000     0.000000     1.000000
# 25%       0.000000     3.000000     2.000000     0.000000     3.000000
# 50%       0.250000     5.000000     4.000000     1.000000     5.000000
# 75%       0.500000     7.000000     5.000000     2.000000     7.000000
# max       1.000000   117.000000    31.000000    86.000000   117.000000
#
#         Accuracy23   Missrate23     Clicks24       Hits24     Misses24  \
# count  1777.000000  1777.000000  1144.000000  1144.000000  1144.000000
# mean      0.700389     0.298485     4.570804     3.384615     1.186189
# std       0.294811     0.294043     4.581551     2.178550     3.577335
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.571429     0.000000     3.000000     2.000000     0.000000
# 50%       0.750000     0.250000     4.000000     3.000000     0.000000
# 75%       1.000000     0.428571     6.000000     5.000000     1.000000
# max       1.000000     1.000000    81.000000    21.000000    60.000000
#
#            Score24   Accuracy24   Missrate24    Clicks25      Hits25  \
# count  1144.000000  1146.000000  1146.000000  432.000000  432.000000
# mean      4.570804     0.773511     0.223872    5.997685    3.979167
# std       4.581551     0.301444     0.299046    6.105985    2.028116
# min       0.000000     0.000000     0.000000    0.000000    0.000000
# 25%       3.000000     0.507353     0.000000    3.000000    2.000000
# 50%       4.000000     1.000000     0.000000    5.000000    4.000000
# 75%       6.000000     1.000000     0.428571    6.000000    6.000000
# max      81.000000     1.000000     1.000000   60.000000   11.000000
#
#          Misses25     Score25  Accuracy25  Missrate25     Clicks26  \
# count  432.000000  432.000000  432.000000  432.000000  1144.000000
# mean     1.981481    5.997685    0.782043    0.195066     7.517483
# std      5.663792    6.105985    0.283597    0.258322     3.812037
# min      0.000000    0.000000    0.000000    0.000000     0.000000
# 25%      0.000000    3.000000    0.666667    0.000000     5.000000
# 50%      1.000000    5.000000    0.857143    0.111111     7.000000
# 75%      1.000000    6.000000    1.000000    0.333333    10.000000
# max     49.000000   60.000000    1.000000    0.933333    50.000000
#
#             Hits26     Misses26      Score26   Accuracy26   Missrate26  \
# count  1144.000000  1144.000000  1144.000000  1146.000000  1146.000000
# mean      4.887238     2.615385     7.517483     0.623873     0.372767
# std       3.116077     2.336662     3.812037     0.257684     0.255823
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     1.000000     5.000000     0.454545     0.222222
# 50%       5.000000     2.000000     7.000000     0.666667     0.333333
# 75%       7.000000     4.000000    10.000000     0.777778     0.545455
# max      16.000000    44.000000    50.000000     1.000000     1.000000
#
#           Clicks27       Hits27     Misses27      Score27   Accuracy27  \
# count  1144.000000  1144.000000  1144.000000  1144.000000  1146.000000
# mean     30.149476     1.753497     1.009615    30.149476     0.053139
# std      21.145652     1.367184     1.683873    21.145652     0.036767
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%      18.000000     1.000000     0.000000    18.000000     0.026316
# 50%      30.000000     2.000000     1.000000    30.000000     0.055556
# 75%      40.000000     3.000000     1.000000    40.000000     0.083333
# max     192.000000     6.000000    17.000000   192.000000     0.111111
#
#         Missrate27     Clicks28       Hits28     Misses28      Score28  \
# count  1146.000000  1143.000000  1143.000000  1143.000000  1143.000000
# mean      0.029488    24.363955     2.397200     1.309711    24.363955
# std       0.031686    13.090571     1.638971     1.678744    13.090571
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.000000    18.000000     1.000000     0.000000    18.000000
# 50%       0.023810    24.000000     2.000000     1.000000    24.000000
# 75%       0.050000    32.000000     3.000000     2.000000    32.000000
# max       0.142857   187.000000     9.000000    24.000000   187.000000
#
#         Accuracy28   Missrate28     Clicks30       Hits30     Misses30  \
# count  1146.000000  1146.000000  1774.000000  1774.000000  1774.000000
# mean      0.098560     0.055452    19.224352     1.145998     2.279030
# std       0.053768     0.052300     3.281553     1.144689     1.191453
# min       0.000000     0.000000     3.000000     0.000000     0.000000
# 25%       0.055556     0.000000    19.000000     0.000000     1.000000
# 50%       0.111111     0.055556    21.000000     1.000000     2.000000
# 75%       0.150000     0.083333    21.000000     2.000000     3.000000
# max       0.166667     0.166667    22.000000     4.000000     4.000000
#
#            Score30   Accuracy30   Missrate30    Clicks31      Hits31  \
# count  1774.000000  1777.000000  1777.000000  431.000000  431.000000
# mean     19.224352     0.056833     0.116240   47.744780    3.354988
# std       3.281553     0.055259     0.057610   22.134574    0.945844
# min       3.000000     0.000000     0.000000   25.000000    0.000000
# 25%      19.000000     0.000000     0.090909   35.000000    3.000000
# 50%      21.000000     0.047619     0.133333   43.000000    4.000000
# 75%      21.000000     0.095238     0.157895   55.000000    4.000000
# max      22.000000     0.190476     0.222222  337.000000    4.000000
#
#          Misses31     Score31  Accuracy31  Missrate31    Clicks32      Hits32  \
# count  431.000000  431.000000  432.000000  432.000000  431.000000  431.000000
# mean     3.238979   47.744780    0.079905    0.050742   50.835267    2.705336
# std      4.960867   22.134574    0.034707    0.052036   30.630176    0.914455
# min      0.000000   25.000000    0.000000    0.000000   18.000000    0.000000
# 25%      0.000000   35.000000    0.050475    0.000000   34.000000    2.000000
# 50%      2.000000   43.000000    0.086957    0.046512   44.000000    3.000000
# 75%      4.000000   55.000000    0.114286    0.090909   57.500000    3.000000
# max     62.000000  337.000000    0.120000    0.186667  378.000000    4.000000
#
#          Misses32     Score32  Accuracy32  Missrate32     Dyslexia
# count  431.000000  431.000000  432.000000  432.000000  1777.000000
# mean     7.661253   50.835267    0.068855    0.124340     0.576252
# std      8.653074   30.630176    0.041420    0.067772     0.494291
# min      0.000000   18.000000    0.000000    0.000000     0.000000
# 25%      2.000000   34.000000    0.040816    0.068966     0.000000
# 50%      6.000000   44.000000    0.063830    0.133333     1.000000
# 75%     10.000000   57.500000    0.086957    0.175883     1.000000
# max    108.000000  378.000000    0.166667    0.315789     1.000000

# %% [markdown]
# Tras observar la distribución de los *dataset* originales y comprobar como sí presentan outliers, se va a proceder con el análisis y la eliminación de aquellos valores que no aporten información válida y vayan a afectar negativamente al modelo.
#
# La función `distplot` se va a emplear para identificar la forma en que los datos están distribuidos, verificando si siguen una distribución normal o no, como afecta la presencia de outliers a la distribución y cual es la media y la desviación estándar. Es decir, se va a representar visualmente la distribución de los datos de cada variable.
#
# La función `boxplot`representa el rango intercuartílico (IQR) de los datos. La caja (gráfico) va desde el primer cuartil (Q1) hasta el tercer cuartil (Q3), y su longitud representa el rango intercuartílico (IQR = Q3 - Q1). Los valores atípicos (outliers) son aquellos que están fuera del rango definido por 1,5 veces el IQR.

# %%
def plot_dist(df):
    
    rest = df.shape[1] % 4
    rows = df.shape[1]//4
    
    if rest == 0:
        rows = rows
    else:
        rows = rows + 1
        
    fig, ax = plt.subplots(ncols = 4, nrows = rows, figsize = (15, 150))
    i = 0
    ax = ax.flatten()

    for col in df.columns:
        plt.title(col)
        sns.distplot(df[col], ax=ax[i])
        i+=1
    plt.tight_layout(pad = 0.5, w_pad = 0.7, h_pad = 2.0)

# %%
def plot_box_whisker(df):
    
    rest = df.shape[1] % 4
    rows = df.shape[1]//4
    
    if rest == 0:
        rows = rows
    else:
        rows = rows + 1

    fig, ax = plt.subplots(ncols = 4, nrows = rows, figsize = (15, 150))
    i = 0
    ax = ax.flatten()
    
    for col in df.columns:
        plt.title(col)
        df.boxplot([col], ax=ax[i])
        i+=1
    plt.tight_layout(pad = 0.5, w_pad = 0.7, h_pad = 2.0)

# %% [markdown]
# Antes de aplicar ningún método de detección de outliers se van a eliminar aquellos valores de *Accuracy* y *Missrate* mayores a 1. Estas variables representan porcentajes, ya que se obtienen de dividir los aciertos y fallos entre el número de cliks, respectivamente. Por ello, de forma manual se van a limpiar los *dataset*.

# %%
#1 DROP
drop_Q = drop_df.drop(columns = ['Gender','Nativelang','Otherlang','Age','Dyslexia'], axis = 1)

#2 ZEROS
zero_Q = zero_df.drop(columns = ['Gender','Nativelang','Otherlang','Age','Dyslexia'], axis = 1)

#3.1 MEAN
mean_Q = mean_df.drop(columns = ['Gender','Nativelang','Otherlang','Age','Dyslexia'], axis = 1)

#3.2 MEDIAN
median_Q = median_df.drop(columns = ['Gender','Nativelang','Otherlang','Age','Dyslexia'], axis = 1)

# %% [markdown]
# ##### Drop

# %%
#plot_dist(drop_Q)

# %%
#plot_box_whisker(drop_Q)

# %% [markdown]
# ##### Zero

# %%
#plot_dist(zero_Q)

# %%
#plot_box_whisker(zero_Q)

# %% [markdown]
# #####  Mean

# %%
#plot_dist(mean_Q)

# %%
#plot_box_whisker(mean_Q)

# %% [markdown]
# ##### Median

# %%
#plot_dist(median_Q)

# %%
#plot_box_whisker(median_Q)

# %% [markdown]
# ### Percentile method

# %% [markdown]
# Para la eleminación de outliers existen varias técnicas, como Z-score method, Inter Quartile Range Method o Percentile method. la técnica que se ha elegido es el método de percentil ya que es fácil de entender y aplicar, y no requiere de una distribución específica. Como se ha podido observar, no todas las variables tienen la misma distribución, lo que podría suponer un problema utilizando Z-score o el método del Intercuartil.
#
# Se trata de un método robusto a la presencia de valores atípicos en los datos, lo que lo hace menos propenso a ser afectado por ellos, y permite ajustar los límites al dataset con el que se esté trabajando. En este caso, para no prescindir de un gran número de datos, aun eliminando aquellos datos que influían negativamente al modelo, se han establecido como umbral superior el 0.999 e inferior el 0.001.

# %%
def remove_outliers(ds):
    print("Old Shape: ", ds.shape)
    
    rng = ds.columns
    for col in rng:
        #first percentile
        min_threshold = ds[col].quantile(0.001)
        #third percentile
        max_threshold = ds[col].quantile(0.999)
        
        ds.drop(ds[(ds[col] < min_threshold) | (ds[col] > max_threshold)].index, inplace=True)
        
    print("New Shape: ", ds.shape)

# %%
#1 DROP
print("DROP")
remove_outliers(drop_Q) 

#2 ZEROS
print("ZEROS")
remove_outliers(zero_Q)

#3.1 MEAN
print("MEAN")
remove_outliers(mean_Q)

#3.2 MEDIAN
print("MEDIAN")
remove_outliers(median_Q)
# Out:
# DROP
# Old Shape:  (431, 186)
# New Shape:  (379, 186)
# ZEROS
# Old Shape:  (1777, 186)
# New Shape:  (1683, 186)
# MEAN
# Old Shape:  (1777, 186)
# New Shape:  (1677, 186)
# MEDIAN
# Old Shape:  (1777, 186)
# New Shape:  (1677, 186)

# %% [markdown]
# Representando de nuevo los gráficos de distribución se puede observar como la presencia de outliers ha disminuido considerablemente:

# %% [markdown]
# ##### DROP

# %%
#plot_dist(drop_Q)

# %% [markdown]
# ##### ZERO

# %%
#plot_dist(zero_Q)

# %% [markdown]
# ##### MEAN

# %%
#plot_dist(train_mean_Q)

# %% [markdown]
# ##### MEDIAN

# %%
#plot_dist(median_Q)

# %% [markdown]
# ### Selección de características

# %% [markdown]
# Se eliminan aquellas filas que contienen valores anómalos de los datasets inciales, recuperando las columnas: 'Gender', 'Nativelang', 'Otherlang', 'Age', 'Dyslexia'

# %%
#1 DROP
drop_df = drop_df.loc[drop_Q.index]

#2 ZEROS
zero_df = zero_df.loc[zero_Q.index]

#3.1 MEAN
mean_df = mean_df.loc[mean_Q.index]

#3.2 MEDIAN
median_df = median_df.loc[median_Q.index]

# %% [markdown]
# Se van a definir dos funciones nuevas, `corr_hit_miss`y `corr_acc_missrate`, para comparar como de correladas están las variables *Clicks*, *Hits*, *Misses* y *Score* y la suma de las variables *Hits y Misses* con *Clicks*.

# %%
def corr_hit_miss(ds, nombre):
    print(nombre+" dataset")
    for i in range(32):
        try:        
            print("Question", str(i+1))
            #Pearson correlation coef
            correlation_misses = ds['Clicks'+str(i+1)].corr(ds['Misses'+str(i+1)])
            correlation_hits = ds['Clicks'+str(i+1)].corr(ds['Hits'+str(i+1)])
            correlation_score = ds['Clicks'+str(i+1)].corr(ds['Score'+str(i+1)])

            ds['Hits + Misses'+str(i+1)] = ds['Hits'+str(i+1)] + ds['Misses'+str(i+1)]
            correlation_sum = ds['Clicks'+str(i+1)].corr(ds['Hits + Misses'+str(i+1)])

            print("Misses", str(i+1), correlation_misses)
            print("Hits", str(i+1), correlation_hits)
            print("Score", str(i+1), correlation_score)
            print("Hits + Misses", str(i+1), correlation_sum)
        except KeyError:
            print("Question "+str(i+1)+" not in the dataset")
            
    print("\n")

# %%
def corr_acc_missrate(ds, nombre):
    print(nombre+" dataset")
    for i in  range(32):
        try:
            print("Question"+str(i+1))
            #Pearson correlation coeff
            correlation_acc = ds['Hits'+str(i+1)].corr(ds['Accuracy'+str(i+1)])
            correlation_missrate = ds['Misses'+str(i+1)].corr(ds['Missrate'+str(i+1)])
            correlation_accs_rate = ds['Accuracy'+str(i+1)].corr(ds['Missrate'+str(i+1)])

            print("Accuracy"+str(i+1),correlation_acc)
            print("Missrate"+str(i+1),correlation_missrate)
            print("Between Accuracy and Missrate"+str(i+1),correlation_accs_rate)
        except KeyError:
            print("Question "+str(i+1)+" not in the dataset")
            
    print("\n")

# %% [markdown]
# Se comprobará tanto para los dataset de entrenamiento, como de prueba y diferenciando entre los cuatro casos distintos tras aplicar las técnicas de gestión de outliers

# %%
#1 DROP
print("DROP")
corr_hit_miss(drop_df, "Model")
#2 ZEROS
print("ZEROS")
corr_hit_miss(zero_df, "Model")
#3.1 MEAN
print("MEAN")
corr_hit_miss(mean_df, "Model")
#3.2 MEDIAN
print("MEDIAN")
corr_hit_miss(median_df, "Model")
# Out:
# DROP
# Model dataset
# Question 1
# Misses 1 0.12868071702187528
# Hits 1 0.9940379265422157
# Score 1 1.0
# Hits + Misses 1 1.0
# Question 2
# Misses 2 0.15608807955378984
# Hits 2 0.992138381060122
# Score 2 1.0
# Hits + Misses 2 1.0
# Question 3
# Misses 3 -0.011867448094136257
# Hits 3 0.9688366217194299
# Score 3 1.0
# Hits + Misses 3 1.0
# Question 4
# Misses 4 0.5864761235958978
# Hits 4 0.19202169159549556
# Score 4 1.0
# Hits + Misses 4 1.0
# Question 5
# Misses 5 -0.18237311857613092
# Hits 5 0.9496439999641498
# Score 5 1.0
# Hits + Misses 5 1.0
# Question 6
# Misses 6 0.04139710920798344
# Hits 6 0.844391567222999
# Score 6 1.0
# Hits + Misses 6 1.0
# Question 7
# Misses 7 0.8236650567355969
# Hits 7 0.9981620657848549
# Score 7 0.9999999999999999
# Hits + Misses 7 0.9999999999999999
# Question 8
# Misses 8 0.2325117029732744
# Hits 8 0.9231833661887592
# Score 8 1.0
# Hits + Misses 8 1.0
# Question 9
# Misses 9 0.8500718327481577
# Hits 9 0.2588488794284018
# Score 9 1.0
# Hits + Misses 9 1.0
# Question 10
# Misses 10 0.872568529445421
# Hits 10 0.06299598468104609
# Score 10 0.9999999999999998
# Hits + Misses 10 0.9999999999999998
# Question 11
# Misses 11 0.5991442956159377
# Hits 11 0.6389202006308565
# Score 11 0.9999999999999999
# Hits + Misses 11 0.9999999999999999
# Question 12
# Misses 12 0.980645331769874
# Hits 12 0.2528132032062641
# Score 12 1.0
# Hits + Misses 12 1.0
# Question 13
# Misses 13 0.9848102359140888
# Hits 13 0.42880328666951856
# Score 13 1.0
# Hits + Misses 13 1.0
# Question 14
# Misses 14 0.07079138991733996
# Hits 14 0.9788163985243775
# Score 14 1.0
# Hits + Misses 14 1.0
# Question 15
# Misses 15 -0.12258058220312157
# Hits 15 0.9898222009561056
# Score 15 1.0
# Hits + Misses 15 1.0
# Question 16
# Misses 16 -0.1960262875904698
# Hits 16 0.9694649862614362
# Score 16 1.0
# Hits + Misses 16 1.0
# Question 17
# Misses 17 0.9812598423771041
# Hits 17 -0.3487421593631945
# Score 17 1.0
# Hits + Misses 17 1.0
# Question 18
# Misses 18 0.9476525197265977
# Hits 18 0.6296471141295994
# Score 18 1.0
# Hits + Misses 18 1.0
# Question 19
# Misses 19 0.9615629314720396
# Hits 19 0.25534737200992
# Score 19 1.0
# Hits + Misses 19 1.0
# Question 20
# Misses 20 0.9463904026321194
# Hits 20 0.36558664767057036
# Score 20 1.0
# Hits + Misses 20 1.0
# Question 21
# Misses 21 0.989774564775021
# Hits 21 0.4948465597779426
# Score 21 1.0
# Hits + Misses 21 1.0
# Question 22
# Misses 22 0.0986983935954181
# Hits 22 0.9130669925717879
# Score 22 1.0
# Hits + Misses 22 1.0
# Question 23
# Misses 23 0.6752522252910335
# Hits 23 0.7839998176070155
# Score 23 0.9999999999999999
# Hits + Misses 23 0.9999999999999999
# Question 24
# Misses 24 0.5616500185773761
# Hits 24 0.7513086004453746
# Score 24 1.0
# Hits + Misses 24 1.0
# Question 25
# Misses 25 0.8478980293970484
# Hits 25 0.40513911382077317
# Score 25 0.9999999999999999
# Hits + Misses 25 0.9999999999999999
# Question 26
# Misses 26 0.35005453698319833
# Hits 26 0.838482998744756
# Score 26 1.0
# Hits + Misses 26 1.0
# Question 27
# Misses 27 0.779564032305343
# Hits 27 0.36841876568646426
# Score 27 1.0
# Hits + Misses 27 0.9892092376817538
# Question 28
# Misses 28 0.13616662931599616
# Hits 28 0.662792891143366
# Score 28 1.0
# Hits + Misses 28 0.9796304042414475
# Question 29
# Question 29 not in the dataset
# Question 30
# Misses 30 -0.017640172418881175
# Hits 30 0.28300365395307714
# Score 30 1.0
# Hits + Misses 30 0.9935547378567928
# Question 31
# Misses 31 0.9634684944858439
# Hits 31 -0.3035263000660286
# Score 31 1.0
# Hits + Misses 31 0.9779521998590592
# Question 32
# Misses 32 0.9574924078426433
# Hits 32 -0.4703897593195407
# Score 32 1.0
# Hits + Misses 32 0.9699059723239581
#
#
# ZEROS
# Model dataset
# Question 1
# Misses 1 -0.029137924985268886
# Hits 1 0.9777658577564614
# Score 1 1.0
# Hits + Misses 1 1.0
# Question 2
# Misses 2 -0.11586793439357776
# Hits 2 0.9599324351137692
# Score 2 1.0
# Hits + Misses 2 1.0
# Question 3
# Misses 3 -0.15688914558722208
# Hits 3 0.9197935238163212
# Score 3 1.0
# Hits + Misses 3 1.0
# Question 4
# Misses 4 0.6496256277052506
# Hits 4 0.22603926758469284
# Score 4 1.0
# Hits + Misses 4 1.0
# Question 5
# Misses 5 -0.16018580210547873
# Hits 5 0.9197772805391738
# Score 5 0.9999999999999999
# Hits + Misses 5 0.9999999999999999
# Question 6
# Misses 6 0.550211635185712
# Hits 6 0.6364848220111313
# Score 6 1.0
# Hits + Misses 6 1.0
# Question 7
# Misses 7 0.4093609232356558
# Hits 7 0.9255721524486464
# Score 7 1.0
# Hits + Misses 7 1.0
# Question 8
# Misses 8 0.40313061801429695
# Hits 8 0.774820072165574
# Score 8 1.0
# Hits + Misses 8 1.0
# Question 9
# Misses 9 0.8199766206102489
# Hits 9 0.32747095752601413
# Score 9 1.0
# Hits + Misses 9 1.0
# Question 10
# Misses 10 0.6111706529222419
# Hits 10 0.53118464089372
# Score 10 0.9999999999999999
# Hits + Misses 10 0.9999999999999999
# Question 11
# Misses 11 0.34438688937107015
# Hits 11 0.7858952459287875
# Score 11 0.9999999999999999
# Hits + Misses 11 0.9999999999999999
# Question 12
# Misses 12 0.9113685126395925
# Hits 12 0.3954720092112284
# Score 12 0.9999999999999998
# Hits + Misses 12 0.9999999999999998
# Question 13
# Misses 13 0.912793388852473
# Hits 13 0.6220409841233583
# Score 13 1.0
# Hits + Misses 13 1.0
# Question 14
# Misses 14 -0.005677100995402587
# Hits 14 0.9359727969284463
# Score 14 0.9999999999999998
# Hits + Misses 14 0.9999999999999998
# Question 15
# Misses 15 0.2817500020996447
# Hits 15 0.8429185167413137
# Score 15 1.0
# Hits + Misses 15 1.0
# Question 16
# Misses 16 0.08526628101401486
# Hits 16 0.9652852161689414
# Score 16 1.0
# Hits + Misses 16 1.0
# Question 17
# Misses 17 0.9182784128498671
# Hits 17 0.1857906429837391
# Score 17 0.9999999999999998
# Hits + Misses 17 0.9999999999999998
# Question 18
# Misses 18 0.8107789997324616
# Hits 18 0.7348042034859433
# Score 18 1.0
# Hits + Misses 18 1.0
# Question 19
# Misses 19 0.880823840115915
# Hits 19 0.5926199352994179
# Score 19 1.0
# Hits + Misses 19 1.0
# Question 20
# Misses 20 0.9390950130906134
# Hits 20 0.5025470648977608
# Score 20 1.0
# Hits + Misses 20 1.0
# Question 21
# Misses 21 0.9881789092631879
# Hits 21 0.6244896747234432
# Score 21 1.0
# Hits + Misses 21 1.0
# Question 22
# Misses 22 0.3280921351394529
# Hits 22 0.76146172544832
# Score 22 0.9999999999999999
# Hits + Misses 22 0.9999999999999999
# Question 23
# Misses 23 0.5760247745760121
# Hits 23 0.6560365491394876
# Score 23 0.9999999999999998
# Hits + Misses 23 0.9999999999999998
# Question 24
# Misses 24 0.6030407690599208
# Hits 24 0.867507283188055
# Score 24 1.0
# Hits + Misses 24 1.0
# Question 25
# Misses 25 0.7784692586235704
# Hits 25 0.8067847569549271
# Score 25 0.9999999999999999
# Hits + Misses 25 0.9999999999999999
# Question 26
# Misses 26 0.7214062276835707
# Hits 26 0.9281378873241579
# Score 26 1.0
# Hits + Misses 26 1.0
# Question 27
# Misses 27 0.7091959018637601
# Hits 27 0.7549585207898585
# Score 27 1.0
# Hits + Misses 27 0.9910890535588679
# Question 28
# Misses 28 0.588378859289576
# Hits 28 0.8175084237581184
# Score 28 1.0
# Hits + Misses 28 0.9947804911688912
# Question 29
# Question 29 not in the dataset
# Question 30
# Misses 30 0.45381845658290976
# Hits 30 0.36776722501252485
# Score 30 1.0
# Hits + Misses 30 0.9463831154072018
# Question 31
# Misses 31 0.823435143949725
# Hits 31 0.846087378303714
# Score 31 1.0
# Hits + Misses 31 0.9786527454372419
# Question 32
# Misses 32 0.9451977448160492
# Hits 32 0.781890365037895
# Score 32 1.0
# Hits + Misses 32 0.989433567786277
#
#
# MEAN
# Model dataset
# Question 1
# Misses 1 -0.02950570025973907
# Hits 1 0.977713091653265
# Score 1 0.9999999999999999
# Hits + Misses 1 0.9999999999999999
# Question 2
# Misses 2 -0.11404363010382775
# Hits 2 0.959713820125563
# Score 2 0.9999999999999998
# Hits + Misses 2 0.9999999999999998
# Question 3
# Misses 3 -0.1558694291870325
# Hits 3 0.9198177557108564
# Score 3 1.0
# Hits + Misses 3 1.0
# Question 4
# Misses 4 0.6495525440711024
# Hits 4 0.2259972584492278
# Score 4 0.9999999999999999
# Hits + Misses 4 0.9999999999999999
# Question 5
# Misses 5 -0.15875744774959838
# Hits 5 0.919733261038183
# Score 5 0.9999999999999999
# Hits + Misses 5 0.9999999999999999
# Question 6
# Misses 6 0.5428415065137288
# Hits 6 0.6392393273301923
# Score 6 1.0
# Hits + Misses 6 1.0
# Question 7
# Misses 7 0.4102172538692994
# Hits 7 0.9259300128836065
# Score 7 0.9999999999999998
# Hits + Misses 7 0.9999999999999998
# Question 8
# Misses 8 0.401587538279427
# Hits 8 0.7748601309474007
# Score 8 1.0
# Hits + Misses 8 1.0
# Question 9
# Misses 9 0.8199682960518209
# Hits 9 0.32738308217497725
# Score 9 1.0
# Hits + Misses 9 1.0
# Question 10
# Misses 10 0.6118480849720601
# Hits 10 0.5297709720490135
# Score 10 1.0
# Hits + Misses 10 1.0
# Question 11
# Misses 11 0.345273159696787
# Hits 11 0.7857028752539403
# Score 11 1.0
# Hits + Misses 11 1.0
# Question 12
# Misses 12 0.9115479729999427
# Hits 12 0.3948323781071826
# Score 12 1.0
# Hits + Misses 12 1.0
# Question 13
# Misses 13 0.9527653146004468
# Hits 13 0.4465568270809856
# Score 13 1.0
# Hits + Misses 13 1.0
# Question 14
# Misses 14 -0.0027502945148647506
# Hits 14 0.9362713497779707
# Score 14 0.9999999999999998
# Hits + Misses 14 0.9999999999999998
# Question 15
# Misses 15 0.28249068337866107
# Hits 15 0.8424181346968608
# Score 15 1.0
# Hits + Misses 15 1.0
# Question 16
# Misses 16 0.08702168365499321
# Hits 16 0.9649035396485234
# Score 16 1.0
# Hits + Misses 16 1.0
# Question 17
# Misses 17 0.918600391154315
# Hits 17 0.1844727015075957
# Score 17 1.0
# Hits + Misses 17 1.0
# Question 18
# Misses 18 0.844067761939994
# Hits 18 0.5548934792304792
# Score 18 1.0
# Hits + Misses 18 1.0
# Question 19
# Misses 19 0.8967705038689425
# Hits 19 0.3098729237984326
# Score 19 1.0
# Hits + Misses 19 0.9859120399286941
# Question 20
# Misses 20 0.9263588362453627
# Hits 20 0.2663843768435096
# Score 20 1.0
# Hits + Misses 20 1.0
# Question 21
# Misses 21 0.9899516489791912
# Hits 21 0.4962356251512035
# Score 21 1.0
# Hits + Misses 21 1.0
# Question 22
# Misses 22 0.32711463398119334
# Hits 22 0.761004908923717
# Score 22 1.0
# Hits + Misses 22 1.0
# Question 23
# Misses 23 0.5771834241011501
# Hits 23 0.6559143724024613
# Score 23 1.0
# Hits + Misses 23 1.0
# Question 24
# Misses 24 0.5702994568684359
# Hits 24 0.7273770630583979
# Score 24 1.0
# Hits + Misses 24 1.0
# Question 25
# Misses 25 0.8566326219349297
# Hits 25 0.40774780895271834
# Score 25 1.0
# Hits + Misses 25 0.9999627953822833
# Question 26
# Misses 26 0.4176440227063561
# Hits 26 0.865885777878
# Score 26 0.9999999999999998
# Hits + Misses 26 0.9999963119739903
# Question 27
# Misses 27 0.672624810560562
# Hits 27 0.5818409393806672
# Score 27 1.0
# Hits + Misses 27 0.9835530501890489
# Question 28
# Misses 28 0.3494610776374178
# Hits 28 0.6353574957929691
# Score 28 1.0
# Hits + Misses 28 0.9850159758075198
# Question 29
# Question 29 not in the dataset
# Question 30
# Misses 30 0.45439904245592677
# Hits 30 0.36895502110909295
# Score 30 1.0
# Hits + Misses 30 0.9467409455268443
# Question 31
# Misses 31 0.9628180678130772
# Hits 31 -0.29069075251562043
# Score 31 1.0
# Hits + Misses 31 0.9779482993540353
# Question 32
# Misses 32 0.9586463029068534
# Hits 32 -0.4626785401005024
# Score 32 1.0
# Hits + Misses 32 0.970582725328403
#
#
# MEDIAN
# Model dataset
# Question 1
# Misses 1 -0.02950570025973907
# Hits 1 0.977713091653265
# Score 1 0.9999999999999999
# Hits + Misses 1 0.9999999999999999
# Question 2
# Misses 2 -0.11404363010382775
# Hits 2 0.959713820125563
# Score 2 0.9999999999999998
# Hits + Misses 2 0.9999999999999998
# Question 3
# Misses 3 -0.1558694291870325
# Hits 3 0.9198177557108564
# Score 3 1.0
# Hits + Misses 3 1.0
# Question 4
# Misses 4 0.6495525440711024
# Hits 4 0.2259972584492278
# Score 4 0.9999999999999999
# Hits + Misses 4 0.9999999999999999
# Question 5
# Misses 5 -0.15875744774959838
# Hits 5 0.919733261038183
# Score 5 0.9999999999999999
# Hits + Misses 5 0.9999999999999999
# Question 6
# Misses 6 0.5428415065137288
# Hits 6 0.6392393273301923
# Score 6 1.0
# Hits + Misses 6 1.0
# Question 7
# Misses 7 0.4102172538692994
# Hits 7 0.9259300128836065
# Score 7 0.9999999999999998
# Hits + Misses 7 0.9999999999999998
# Question 8
# Misses 8 0.401587538279427
# Hits 8 0.7748601309474007
# Score 8 1.0
# Hits + Misses 8 1.0
# Question 9
# Misses 9 0.8199682960518209
# Hits 9 0.32738308217497725
# Score 9 1.0
# Hits + Misses 9 1.0
# Question 10
# Misses 10 0.6118480849720601
# Hits 10 0.5297709720490135
# Score 10 1.0
# Hits + Misses 10 1.0
# Question 11
# Misses 11 0.345273159696787
# Hits 11 0.7857028752539403
# Score 11 1.0
# Hits + Misses 11 1.0
# Question 12
# Misses 12 0.9115479729999427
# Hits 12 0.3948323781071826
# Score 12 1.0
# Hits + Misses 12 1.0
# Question 13
# Misses 13 0.9525512357252033
# Hits 13 0.45580593994054713
# Score 13 1.0
# Hits + Misses 13 1.0
# Question 14
# Misses 14 -0.0027502945148647506
# Hits 14 0.9362713497779707
# Score 14 0.9999999999999998
# Hits + Misses 14 0.9999999999999998
# Question 15
# Misses 15 0.28249068337866107
# Hits 15 0.8424181346968608
# Score 15 1.0
# Hits + Misses 15 1.0
# Question 16
# Misses 16 0.08702168365499321
# Hits 16 0.9649035396485234
# Score 16 1.0
# Hits + Misses 16 1.0
# Question 17
# Misses 17 0.918600391154315
# Hits 17 0.1844727015075957
# Score 17 1.0
# Hits + Misses 17 1.0
# Question 18
# Misses 18 0.8443643704563605
# Hits 18 0.5538400002120638
# Score 18 1.0
# Hits + Misses 18 1.0
# Question 19
# Misses 19 0.8942220278837081
# Hits 19 0.31502448153582
# Score 19 1.0
# Hits + Misses 19 0.9738486886853849
# Question 20
# Misses 20 0.927815798346264
# Hits 20 0.27162467271892304
# Score 20 1.0
# Hits + Misses 20 1.0
# Question 21
# Misses 21 0.9901763813844768
# Hits 21 0.4979425899694767
# Score 21 1.0
# Hits + Misses 21 1.0
# Question 22
# Misses 22 0.32713305489313427
# Hits 22 0.7609914492704618
# Score 22 1.0
# Hits + Misses 22 1.0
# Question 23
# Misses 23 0.5771552543981466
# Hits 23 0.6558865970109508
# Score 23 0.9999999999999998
# Hits + Misses 23 0.9999999999999998
# Question 24
# Misses 24 0.545420363629016
# Hits 24 0.7271279508894408
# Score 24 1.0
# Hits + Misses 24 0.9684495706986621
# Question 25
# Misses 25 0.85517496682794
# Hits 25 0.39384574874498507
# Score 25 1.0
# Hits + Misses 25 1.0
# Question 26
# Misses 26 0.416876264770644
# Hits 26 0.8619291605977549
# Score 26 1.0
# Hits + Misses 26 1.0
# Question 27
# Misses 27 0.6725103631160281
# Hits 27 0.581772042578686
# Score 27 1.0
# Hits + Misses 27 0.9800391105760217
# Question 28
# Misses 28 0.3414173036635705
# Hits 28 0.6238695977149545
# Score 28 1.0
# Hits + Misses 28 0.9485672319044711
# Question 29
# Question 29 not in the dataset
# Question 30
# Misses 30 0.45412471709864305
# Hits 30 0.36882504151676165
# Score 30 1.0
# Hits + Misses 30 0.9462018180225212
# Question 31
# Misses 31 0.9638850153467993
# Hits 31 -0.34586131849223056
# Score 31 1.0
# Hits + Misses 31 0.9740215871879633
# Question 32
# Misses 32 0.9580543674698638
# Hits 32 -0.4840133384558291
# Score 32 0.9999999999999998
# Hits + Misses 32 0.9679172612292891

# %%
#1 DROP
print("DROP")
corr_acc_missrate(drop_df, "Model")
#2 ZEROS
print("ZEROS")
corr_acc_missrate(zero_df, "Model")
#3.1 MEAN
print("MEAN")
corr_acc_missrate(mean_df, "Model")
#3.2 MEDIAN
print("MEDIAN")
corr_acc_missrate(median_df, "Model")
# Out:
# DROP
# Model dataset
# Question1
# Accuracy1 0.13012145017933385
# Missrate1 0.8315910346572517
# Between Accuracy and Missrate1 -1.0
# Question2
# Accuracy2 0.08067294362390957
# Missrate2 0.9493386404504637
# Between Accuracy and Missrate2 -0.9999999999999991
# Question3
# Accuracy3 0.3290890735276428
# Missrate3 0.9139488489452116
# Between Accuracy and Missrate3 -0.9999999999999999
# Question4
# Accuracy4 0.7236349851015108
# Missrate4 0.9593966219611636
# Between Accuracy and Missrate4 -0.9999999999999999
# Question5
# Accuracy5 0.5348287344719569
# Missrate5 0.9734003240850211
# Between Accuracy and Missrate5 -1.0
# Question6
# Accuracy6 0.6683039835384843
# Missrate6 0.9315935354821657
# Between Accuracy and Missrate6 -1.0
# Question7
# Accuracy7 0.027746366280564264
# Missrate7 0.4789916066472778
# Between Accuracy and Missrate7 -0.7869027057641799
# Question8
# Accuracy8 0.22115148761193354
# Missrate8 0.9774046998911736
# Between Accuracy and Missrate8 -1.0
# Question9
# Accuracy9 0.6560115584218659
# Missrate9 0.638745089298645
# Between Accuracy and Missrate9 -1.0
# Question10
# Accuracy10 0.7783188945176014
# Missrate10 0.770123038273314
# Between Accuracy and Missrate10 -1.0
# Question11
# Accuracy11 0.5766421431773611
# Missrate11 0.745189774198184
# Between Accuracy and Missrate11 -0.9999999999999999
# Question12
# Accuracy12 0.30822866073043015
# Missrate12 0.7858711847521032
# Between Accuracy and Missrate12 -0.9419416988124101
# Question13
# Accuracy13 0.2881309629956868
# Missrate13 0.6405569014506778
# Between Accuracy and Missrate13 -1.0
# Question14
# Accuracy14 0.40763971199525056
# Missrate14 0.8205466622864779
# Between Accuracy and Missrate14 -1.0
# Question15
# Accuracy15 0.40324969976050246
# Missrate15 0.7688364347609444
# Between Accuracy and Missrate15 -1.0
# Question16
# Accuracy16 0.45923680739651473
# Missrate16 0.965899617836206
# Between Accuracy and Missrate16 -1.0
# Question17
# Accuracy17 0.5676265445440858
# Missrate17 0.9219973697730182
# Between Accuracy and Missrate17 -1.0
# Question18
# Accuracy18 0.34168480825133846
# Missrate18 0.5524042211731626
# Between Accuracy and Missrate18 -1.0
# Question19
# Accuracy19 0.5887148498088581
# Missrate19 0.5933296260248098
# Between Accuracy and Missrate19 -1.0
# Question20
# Accuracy20 0.6210207956101268
# Missrate20 0.4781244700700131
# Between Accuracy and Missrate20 -1.0
# Question21
# Accuracy21 0.6402000748076839
# Missrate21 0.2939659927967891
# Between Accuracy and Missrate21 -0.9999999999999994
# Question22
# Accuracy22 0.569285390512449
# Missrate22 0.9031570836727758
# Between Accuracy and Missrate22 -1.0
# Question23
# Accuracy23 0.3856053394778745
# Missrate23 0.7690049033236341
# Between Accuracy and Missrate23 -1.0
# Question24
# Accuracy24 0.4993610945814543
# Missrate24 0.6527595770921675
# Between Accuracy and Missrate24 -0.9999999999999993
# Question25
# Accuracy25 0.535195447663058
# Missrate25 0.8123435153147515
# Between Accuracy and Missrate25 -0.8384860550219059
# Question26
# Accuracy26 0.6043248087596215
# Missrate26 0.8134976010283803
# Between Accuracy and Missrate26 -1.0
# Question27
# Accuracy27 0.762662931903285
# Missrate27 0.7224478119956361
# Between Accuracy and Missrate27 -0.47017733841399245
# Question28
# Accuracy28 0.7843358139941267
# Missrate28 0.8304332891229859
# Between Accuracy and Missrate28 -0.9737179678587197
# Question29
# Question 29 not in the dataset
# Question30
# Accuracy30 0.9999435192851425
# Missrate30 0.9727077684730641
# Between Accuracy and Missrate30 -0.9986359865048225
# Question31
# Accuracy31 0.8608039018937859
# Missrate31 0.9010807208128827
# Between Accuracy and Missrate31 -0.9366607535636337
# Question32
# Accuracy32 0.8411068537720358
# Missrate32 0.8556025431396878
# Between Accuracy and Missrate32 -0.92340488238258
#
#
# ZEROS
# Model dataset
# Question1
# Accuracy1 0.4613012018032771
# Missrate1 0.7640762437867501
# Between Accuracy and Missrate1 -0.8788458710511071
# Question2
# Accuracy2 0.5117407526773119
# Missrate2 0.8771974943742508
# Between Accuracy and Missrate2 -0.9736487742051899
# Question3
# Accuracy3 0.6182626063640843
# Missrate3 0.8846920934835004
# Between Accuracy and Missrate3 -0.9999999999999999
# Question4
# Accuracy4 0.7153812137328268
# Missrate4 0.8544166562821094
# Between Accuracy and Missrate4 -0.9892302287172813
# Question5
# Accuracy5 0.6715834965535801
# Missrate5 0.8398381830425523
# Between Accuracy and Missrate5 -1.0
# Question6
# Accuracy6 0.7327125229352071
# Missrate6 0.6501602964993967
# Between Accuracy and Missrate6 -0.9925644475278744
# Question7
# Accuracy7 0.2828652231213225
# Missrate7 0.5391106688667889
# Between Accuracy and Missrate7 -0.9181610601485813
# Question8
# Accuracy8 0.4994020495946765
# Missrate8 0.7309492224999701
# Between Accuracy and Missrate8 -1.0
# Question9
# Accuracy9 0.6727986320441655
# Missrate9 0.5973859482746249
# Between Accuracy and Missrate9 -0.9939138029199103
# Question10
# Accuracy10 0.6966377866874308
# Missrate10 0.6247567671661577
# Between Accuracy and Missrate10 -0.9899445920357037
# Question11
# Accuracy11 0.6410562268355772
# Missrate11 0.7107508729887031
# Between Accuracy and Missrate11 -0.9881987900925678
# Question12
# Accuracy12 0.5514936705283486
# Missrate12 0.46325654818893736
# Between Accuracy and Missrate12 -0.9824020389011502
# Question13
# Accuracy13 0.828553756963598
# Missrate13 0.47802994881847366
# Between Accuracy and Missrate13 -0.018633944106356617
# Question14
# Accuracy14 0.4452106314699777
# Missrate14 0.952646910736137
# Between Accuracy and Missrate14 -0.9999999999999967
# Question15
# Accuracy15 0.5088338977313714
# Missrate15 0.6588321949482121
# Between Accuracy and Missrate15 -0.8568161226869522
# Question16
# Accuracy16 0.26335331037041565
# Missrate16 0.9352973841744799
# Between Accuracy and Missrate16 -1.0
# Question17
# Accuracy17 0.432152427798599
# Missrate17 0.5581038767934399
# Between Accuracy and Missrate17 -0.9421079536723889
# Question18
# Accuracy18 0.8555480609496975
# Missrate18 0.5634044874256808
# Between Accuracy and Missrate18 -0.2129253568877878
# Question19
# Accuracy19 0.8439044879865124
# Missrate19 0.5894078449728748
# Between Accuracy and Missrate19 -0.07792718430624059
# Question20
# Accuracy20 0.8030315256328364
# Missrate20 0.6500218064093939
# Between Accuracy and Missrate20 -0.12940532185203255
# Question21
# Accuracy21 0.7939647056615607
# Missrate21 0.4630322562897102
# Between Accuracy and Missrate21 0.12444957035765357
# Question22
# Accuracy22 0.6612307029611296
# Missrate22 0.7896875800115372
# Between Accuracy and Missrate22 -0.9835557566528175
# Question23
# Accuracy23 0.6194056057657095
# Missrate23 0.6996152845496698
# Between Accuracy and Missrate23 -1.0
# Question24
# Accuracy24 0.8121738846035416
# Missrate24 0.7160037840663454
# Between Accuracy and Missrate24 -0.14106000980825478
# Question25
# Accuracy25 0.9016363320899656
# Missrate25 0.8291316278586751
# Between Accuracy and Missrate25 0.2581957428365136
# Question26
# Accuracy26 0.8327837727506644
# Missrate26 0.7936765776562785
# Between Accuracy and Missrate26 0.1252113765274226
# Question27
# Accuracy27 0.8755184833153103
# Missrate27 0.6850629667411302
# Between Accuracy and Missrate27 -0.02520327006905242
# Question28
# Accuracy28 0.8529802444800568
# Missrate28 0.8229929713020414
# Between Accuracy and Missrate28 -0.13389067549287434
# Question29
# Question 29 not in the dataset
# Question30
# Accuracy30 0.9860944640030802
# Missrate30 0.9494989993862631
# Between Accuracy and Missrate30 -0.7775121488881572
# Question31
# Accuracy31 0.969589590449277
# Missrate31 0.9318420240242297
# Between Accuracy and Missrate31 0.2845410566813331
# Question32
# Accuracy32 0.9433919778119346
# Missrate32 0.9251307108112145
# Between Accuracy and Missrate32 0.48064221042464633
#
#
# MEAN
# Model dataset
# Question1
# Accuracy1 0.46177417603725285
# Missrate1 0.764095998800316
# Between Accuracy and Missrate1 -0.8787865904024514
# Question2
# Accuracy2 0.509226476045974
# Missrate2 0.8815695755991012
# Between Accuracy and Missrate2 -0.973222467866249
# Question3
# Accuracy3 0.6173476663295592
# Missrate3 0.8841507017537251
# Between Accuracy and Missrate3 -1.0
# Question4
# Accuracy4 0.7165659961760928
# Missrate4 0.8532772851592976
# Between Accuracy and Missrate4 -0.9892257518718464
# Question5
# Accuracy5 0.6704880786396672
# Missrate5 0.8399283991762377
# Between Accuracy and Missrate5 -1.0
# Question6
# Accuracy6 0.7318963295359845
# Missrate6 0.6525596017102633
# Between Accuracy and Missrate6 -0.9975046372784597
# Question7
# Accuracy7 0.2820640479773435
# Missrate7 0.5363370877022877
# Between Accuracy and Missrate7 -0.9176879147730861
# Question8
# Accuracy8 0.501432472402051
# Missrate8 0.7301280895502883
# Between Accuracy and Missrate8 -1.0
# Question9
# Accuracy9 0.6737566176155436
# Missrate9 0.5968431382093242
# Between Accuracy and Missrate9 -0.993898738284219
# Question10
# Accuracy10 0.6957870640569161
# Missrate10 0.6246261506088111
# Between Accuracy and Missrate10 -0.993266793301419
# Question11
# Accuracy11 0.6411716730796156
# Missrate11 0.7100082727241661
# Between Accuracy and Missrate11 -0.9881640225129859
# Question12
# Accuracy12 0.5505378820912435
# Missrate12 0.46310417343525984
# Between Accuracy and Missrate12 -0.9858539569322301
# Question13
# Accuracy13 0.513131205426081
# Missrate13 0.44632955083187525
# Between Accuracy and Missrate13 -0.9999980904634036
# Question14
# Accuracy14 0.4418185551160483
# Missrate14 0.9525763134176334
# Between Accuracy and Missrate14 -1.0
# Question15
# Accuracy15 0.5093331974541019
# Missrate15 0.658666594807407
# Between Accuracy and Missrate15 -0.8567284299057667
# Question16
# Accuracy16 0.2635016146733538
# Missrate16 0.9353337894517916
# Between Accuracy and Missrate16 -1.0
# Question17
# Accuracy17 0.4343403865936367
# Missrate17 0.5578324094798593
# Between Accuracy and Missrate17 -0.9419096804940693
# Question18
# Accuracy18 0.6978889637619186
# Missrate18 0.5117101610452226
# Between Accuracy and Missrate18 -0.9809981412185935
# Question19
# Accuracy19 0.6728808432037653
# Missrate19 0.5275806507134365
# Between Accuracy and Missrate19 -0.9930283639969526
# Question20
# Accuracy20 0.7257289159288892
# Missrate20 0.4748346797812102
# Between Accuracy and Missrate20 -0.9913272561488489
# Question21
# Accuracy21 0.6437519050091353
# Missrate21 0.29454497490992293
# Between Accuracy and Missrate21 -0.9999405074145346
# Question22
# Accuracy22 0.6599559282225615
# Missrate22 0.7888602737574191
# Between Accuracy and Missrate22 -0.9770195685100067
# Question23
# Accuracy23 0.6161737117117764
# Missrate23 0.6985352547816426
# Between Accuracy and Missrate23 -0.9931145151086448
# Question24
# Accuracy24 0.5638763537795441
# Missrate24 0.6725681650469194
# Between Accuracy and Missrate24 -0.9895536050195253
# Question25
# Accuracy25 0.5225394572172727
# Missrate25 0.8080186744576427
# Between Accuracy and Missrate25 -0.8385680782155622
# Question26
# Accuracy26 0.6438496012482927
# Missrate26 0.6255993451600702
# Between Accuracy and Missrate26 -0.9858790762663144
# Question27
# Accuracy27 0.79059030089962
# Missrate27 0.6209023545898783
# Between Accuracy and Missrate27 -0.5196333377009716
# Question28
# Accuracy28 0.7173856709867739
# Missrate28 0.7556924033781327
# Between Accuracy and Missrate28 -0.9468986828478396
# Question29
# Question 29 not in the dataset
# Question30
# Accuracy30 0.9867119308926801
# Missrate30 0.9466547680856225
# Between Accuracy and Missrate30 -0.7704932963054554
# Question31
# Accuracy31 0.8535629493536923
# Missrate31 0.9005512131240697
# Between Accuracy and Missrate31 -0.9362659004643308
# Question32
# Accuracy32 0.8330922545586468
# Missrate32 0.8484633481203715
# Between Accuracy and Missrate32 -0.9215372161097974
#
#
# MEDIAN
# Model dataset
# Question1
# Accuracy1 0.46177417603725285
# Missrate1 0.764095998800316
# Between Accuracy and Missrate1 -0.8787865904024514
# Question2
# Accuracy2 0.509226476045974
# Missrate2 0.8815695755991012
# Between Accuracy and Missrate2 -0.973222467866249
# Question3
# Accuracy3 0.6173476663295592
# Missrate3 0.8841507017537251
# Between Accuracy and Missrate3 -1.0
# Question4
# Accuracy4 0.7165659961760928
# Missrate4 0.8532772851592976
# Between Accuracy and Missrate4 -0.9892257518718464
# Question5
# Accuracy5 0.6704880786396672
# Missrate5 0.8399283991762377
# Between Accuracy and Missrate5 -1.0
# Question6
# Accuracy6 0.7318963295359845
# Missrate6 0.6525596017102633
# Between Accuracy and Missrate6 -0.9975046372784597
# Question7
# Accuracy7 0.2820640479773435
# Missrate7 0.5363370877022877
# Between Accuracy and Missrate7 -0.9176879147730861
# Question8
# Accuracy8 0.501432472402051
# Missrate8 0.7301280895502883
# Between Accuracy and Missrate8 -1.0
# Question9
# Accuracy9 0.6737566176155436
# Missrate9 0.5968431382093242
# Between Accuracy and Missrate9 -0.993898738284219
# Question10
# Accuracy10 0.6957870640569161
# Missrate10 0.6246261506088111
# Between Accuracy and Missrate10 -0.993266793301419
# Question11
# Accuracy11 0.6411716730796156
# Missrate11 0.7100082727241661
# Between Accuracy and Missrate11 -0.9881640225129859
# Question12
# Accuracy12 0.5505378820912435
# Missrate12 0.46310417343525984
# Between Accuracy and Missrate12 -0.9858539569322301
# Question13
# Accuracy13 0.4847959206430407
# Missrate13 0.4517265325383919
# Between Accuracy and Missrate13 -0.9999999999999999
# Question14
# Accuracy14 0.4418185551160483
# Missrate14 0.9525763134176334
# Between Accuracy and Missrate14 -1.0
# Question15
# Accuracy15 0.5093331974541019
# Missrate15 0.658666594807407
# Between Accuracy and Missrate15 -0.8567284299057667
# Question16
# Accuracy16 0.2635016146733538
# Missrate16 0.9353337894517916
# Between Accuracy and Missrate16 -1.0
# Question17
# Accuracy17 0.4343403865936367
# Missrate17 0.5578324094798593
# Between Accuracy and Missrate17 -0.9419096804940693
# Question18
# Accuracy18 0.6882191889300091
# Missrate18 0.5156436270853287
# Between Accuracy and Missrate18 -0.9814610165867106
# Question19
# Accuracy19 0.645055321416542
# Missrate19 0.5318064915371264
# Between Accuracy and Missrate19 -0.9930708973047441
# Question20
# Accuracy20 0.7255525342210127
# Missrate20 0.46953902835337796
# Between Accuracy and Missrate20 -0.9913272136951568
# Question21
# Accuracy21 0.6455082314711656
# Missrate21 0.27839549448093354
# Between Accuracy and Missrate21 -1.0
# Question22
# Accuracy22 0.6603024589952016
# Missrate22 0.7894972733098298
# Between Accuracy and Missrate22 -0.9770195685100067
# Question23
# Accuracy23 0.6157750399567165
# Missrate23 0.6990588511258248
# Between Accuracy and Missrate23 -0.9931145151086448
# Question24
# Accuracy24 0.48715699582484084
# Missrate24 0.7176482666668466
# Between Accuracy and Missrate24 -0.9913546067422837
# Question25
# Accuracy25 0.5268942031442512
# Missrate25 0.8110468020749935
# Between Accuracy and Missrate25 -0.8473109085515579
# Question26
# Accuracy26 0.6448322558464141
# Missrate26 0.6320268120362822
# Between Accuracy and Missrate26 -0.986016926895362
# Question27
# Accuracy27 0.7882979235440066
# Missrate27 0.6142785528192007
# Between Accuracy and Missrate27 -0.5202624394737739
# Question28
# Accuracy28 0.6876498828681814
# Missrate28 0.7526071598954924
# Between Accuracy and Missrate28 -0.9381862415224419
# Question29
# Question 29 not in the dataset
# Question30
# Accuracy30 0.9868679167741704
# Missrate30 0.9472103630592824
# Between Accuracy and Missrate30 -0.7704932963054554
# Question31
# Accuracy31 0.8097806534726305
# Missrate31 0.8920442619164486
# Between Accuracy and Missrate31 -0.9321364314524924
# Question32
# Accuracy32 0.765336507296945
# Missrate32 0.8186591567722856
# Between Accuracy and Missrate32 -0.9227305038063045

# %%
for i in range(32):
    columns = ['Accuracy'+str(i+1), 'Missrate'+str(i+1), 'Score'+str(i+1)]
    try:
        # 1 DROP
        drop_df = drop_df.drop(columns, axis=1)

        # 2 ZEROS
        zero_df = zero_df.drop(columns, axis=1)

        # 3.1 MEAN
        mean_df = mean_df.drop(columns, axis=1)

        # 3.2 MEDIAN
        median_df = median_df.drop(columns, axis=1)
    except KeyError:
        print("Colmuns not found: ",columns)
# Out:
# Colmuns not found:  ['Accuracy29', 'Missrate29', 'Score29']

# %% [markdown]
# ### Divide data

# %% [markdown]
# Tras realizar la limpieza y preparar los datos que se van a emplear para diseñar el modelo, se va a proceder con la separación entre las variables que se van a empelar para entrenar el modelo y la variable que se quiere predecir. Es decir, se va a diferenciar entre **X**, set con todas las variables excepto si una persona es disléxica o no, e **y**, set que contiene los valores corresondientes a la variable *Dyslexia*.

# %%
from sklearn.model_selection import train_test_split

#1 DROP
y_drop_pre = drop_df['Dyslexia']
X_drop_pre = drop_df.loc[:, drop_df.columns != 'Dyslexia']
X_drop, X_test_drop, y_drop, y_test_drop = train_test_split(X_drop_pre, y_drop_pre, test_size=0.2, random_state=4)

#2 ZEROS
y_zero_pre = zero_df['Dyslexia']
X_zero_pre = zero_df.loc[:, zero_df.columns != 'Dyslexia']
X_zero, X_test_zero, y_zero, y_test_zero = train_test_split(X_zero_pre, y_zero_pre, test_size=0.2, random_state=4, stratify = y_zero_pre)

#3.1 MEAN
y_mean_pre = mean_df['Dyslexia']
X_mean_pre = mean_df.loc[:, mean_df.columns != 'Dyslexia']
X_mean, X_test_mean, y_mean, y_test_mean = train_test_split(X_mean_pre, y_mean_pre, test_size=0.2, random_state=4, stratify = y_mean_pre)

#3.2 MEDIAN
y_median_pre = median_df['Dyslexia']
X_median_pre = median_df.loc[:, median_df.columns != 'Dyslexia']
X_median, X_test_median, y_median, y_test_median = train_test_split(X_median_pre, y_median_pre, test_size=0.2, random_state=4, stratify = y_median_pre)

# %% [markdown]
# ## Modeling Training

# %%
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score, jaccard_score

# %% [markdown]
# Se va a proceder a entrenar el modelo. Como se mencionó al inicio del documento se van a emplear cinco algoritmos distintos de Machine Learning, de los cuales se eligirá el que prediga los casos positivos y negativos.
#
# Antes de comenzar con el entrenamiento del modelo se van a definir varias funciones con el objetivo de simplificar el código:
#
# - `plot_confusion_matrix(cm, classes)`: toma como argumentos de entrada la matriz de confusión del modelo y los valores que se quieren evaluar, en este caso 0's y 1's. Mostrará por pantalla la representación de los aciertos y fallos comparando que casos se han predicho correctamente y cuales no.
# - `knn_accuracy(X_train, y_train, X_test, y_test, Ks)`: uno de los algoritmos de Machine Learning que se va a entrenar es K-Nearest Neighbors, por lo que es necesario escoger cuidadosamente el número de clusters con el que se va a entrenar el modelo. Mediante esta función, pasando como argumentos de entrada los datos usados para el train y el test y el máximo de clusters que se quieren probar, se imprimirá por pantalla la exactitud (*accuracy*) que tiene el modelo en función de los distintos valores de k
# - `k_fold_cv(X, y, n, model)`: K-fold  cross-validation se emplea como técnica de evaluación del modelo recursiva. Pasando como argumentos de entrada los datos, el modelo que se quiere testear y la cantidad de iteración que se van a realizar, la función va a dividir de diferente forma los datos n veces y calcular la media de los resultados obtenidos en cada iteración al final. Se ha especificado que devuelva la excatitud del modelo (*score*) y el F1-score de las dos clases, es decir, tanto de los 0's como de los 1's
# - `evaluate_model(X_train, y_train, X_test, y_test, model)`: esta función va a devolver distintas evaluaciones del modelo, como por ejemplo *Recall*, *Accuracy*, *Jaccard index* o *F1-score*, así como la representación de la matriz de confusión del modelo que se especifique.

# %%
import itertools

def plot_confusion_matrix(cm, classes):
    # Create figure and axes
    fig, ax = plt.subplots()
    im = ax.imshow(cm, cmap='Blues')

    #add value count to each cell
    fmt = 'd'
    thresh = cm.max() / 3.
    
    #labels value count
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    #set axis labels
    ax.set_xticks(np.arange(len(classes)))
    ax.set_yticks(np.arange(len(classes)))
    ax.set_xticklabels(classes)
    ax.set_yticklabels(classes)
    ax.set_ylabel('True label')
    ax.set_xlabel('Predicted label')

    #colorbar
    cbar = ax.figure.colorbar(im, ax=ax)

    plt.show()

# %%
#calculate nº clusters KNN
def knn_accuracy(X_train, y_train, X_test, y_test, Ks):
    
    for n in range(1,Ks):
        model = KNeighborsClassifier(n_neighbors=n).fit(X_train, y_train)
        y_hat = model.predict(X_test)
        
        acc = metrics.accuracy_score(y_test, y_hat)
        print(f"Value of k: {n} - Accuracy: {acc:.2f}")

# %%
def k_fold_cv(X, y, n, model):
    kf = KFold(n_splits = n)
    
    X = pd.DataFrame(X)
    y = pd.DataFrame(y)
    
    #accuracy
    scores = []
    
    for train_index, test_index in kf.split(X):
        X_train, X_test = X.iloc[train_index].values, X.iloc[test_index].values
        y_train, y_test = y.iloc[train_index].values, y.iloc[test_index].values
        #model prediction 
        y_hat = model.predict(X_test)
        #evaluate the performance of a model (accuracy score)
        score = model.score(X_test,y_test)
        scores.append(score)
          
    return "Accuracy: "+str(np.mean(scores))

# %%
def evaluate_model(X_train, y_train, X_test, y_test, model):
    
    y_hat = model.predict(X_test)
    
    #different evaluations
    print("Train set Accuracy: ", metrics.accuracy_score(y_train, model.predict(X_train)))
    print("Test set Accuracy: ", metrics.accuracy_score(y_test, y_hat))
    print("F1 score: ", f1_score(y_test, y_hat))
    print("Recall 0's: ", recall_score(y_test, y_hat, pos_label=0))
    print("Recall 1's: ", recall_score(y_test, y_hat, pos_label=1))
    print("Jaccard index 0's: ", jaccard_score(y_test, y_hat, pos_label = 0))
    print("Jaccard index 1's: ", jaccard_score(y_test, y_hat, pos_label = 1))
    print("\n")
    
    #classification report
    print (classification_report(y_test, y_hat))
    print("\n")

    #compute confusion matrix
    cm = confusion_matrix(y_test, y_hat, labels=[0,1])
    np.set_printoptions(precision = 2)

    #plot confusion matrix
    plt.figure()
    plot_confusion_matrix(cm, classes=['No = 0','Yes = 1'])

# %% [markdown]
# ## 1. K-Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ### 1.1. Drop Values

# %%
# Values used to train the model: X_drop, y_drop
# Values used to test the model: X_test_drop, y_test_drop

# Data Standardization -> Good practice working with KNN (based on the distance)
X_drop_KNN = preprocessing.StandardScaler().fit(X_drop).transform(X_drop.astype(float))
X_test_drop_KNN = preprocessing.StandardScaler().fit(X_test_drop).transform(X_test_drop.astype(float))

# %%
knn_accuracy(X_drop_KNN, y_drop, X_test_drop_KNN, y_test_drop, 10)
# Out:
# Value of k: 1 - Accuracy: 0.97
# Value of k: 2 - Accuracy: 0.97
# Value of k: 3 - Accuracy: 0.92
# Value of k: 4 - Accuracy: 0.88
# Value of k: 5 - Accuracy: 0.82
# Value of k: 6 - Accuracy: 0.82
# Value of k: 7 - Accuracy: 0.80
# Value of k: 8 - Accuracy: 0.80
# Value of k: 9 - Accuracy: 0.84

# %%
k = 2
#Train Model and Predict  
neigh_drop = KNeighborsClassifier(n_neighbors = k).fit(X_drop_KNN,y_drop)
y_hat_drop_KNN = neigh_drop.predict(X_test_drop_KNN)

# %%
k_fold_cv(X_drop_KNN, y_drop, 10, neigh_drop)
# Out:
# 'Accuracy: 1.0'

# %%
evaluate_model(X_drop_KNN, y_drop, X_test_drop_KNN, y_test_drop, neigh_drop)
# Out:
# Train set Accuracy:  1.0
# Test set Accuracy:  0.9736842105263158
# F1 score:  0.9743589743589743
# Recall 0's:  0.9473684210526315
# Recall 1's:  1.0
# Jaccard index 0's:  0.9473684210526315
# Jaccard index 1's:  0.95
#
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.95      0.97        38
#          1.0       0.95      1.00      0.97        38
#
#     accuracy                           0.97        76
#    macro avg       0.97      0.97      0.97        76
# weighted avg       0.97      0.97      0.97        76

# %% [markdown]
# ### 1.2. Zero Values

# %%
# Values used to train the model: X_zero, y_zero
# Values used to test the model: X_test_zero, y_test_zero

# Data Standardization -> Good practice working with KNN (based on the distance)
X_zero_KNN = preprocessing.StandardScaler().fit(X_zero).transform(X_zero.astype(float))
X_test_zero_KNN = preprocessing.StandardScaler().fit(X_test_zero).transform(X_test_zero.astype(float))

# %%
knn_accuracy(X_zero_KNN, y_zero, X_test_zero_KNN, y_test_zero, 10)
# Out:
# Value of k: 1 - Accuracy: 0.94
# Value of k: 2 - Accuracy: 0.94
# Value of k: 3 - Accuracy: 0.90
# Value of k: 4 - Accuracy: 0.90
# Value of k: 5 - Accuracy: 0.87
# Value of k: 6 - Accuracy: 0.84
# Value of k: 7 - Accuracy: 0.81
# Value of k: 8 - Accuracy: 0.80
# Value of k: 9 - Accuracy: 0.80

# %%
k = 1
#Train Model and Predict  
neigh_zero = KNeighborsClassifier(n_neighbors = k).fit(X_zero_KNN,y_zero)
y_hat_zero_KNN = neigh_zero.predict(X_test_zero_KNN)

# %%
k_fold_cv(X_zero_KNN, y_zero, 10, neigh_zero)
# Out:
# 'Accuracy: 1.0'

# %%
evaluate_model(X_zero_KNN, y_zero, X_test_zero_KNN, y_test_zero, neigh_zero)
# Out:
# Train set Accuracy:  1.0
# Test set Accuracy:  0.9406528189910979
# F1 score:  0.9534883720930233
# Recall 0's:  0.8484848484848485
# Recall 1's:  1.0
# Jaccard index 0's:  0.8484848484848485
# Jaccard index 1's:  0.9111111111111111
#
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.85      0.92       132
#          1.0       0.91      1.00      0.95       205
#
#     accuracy                           0.94       337
#    macro avg       0.96      0.92      0.94       337
# weighted avg       0.95      0.94      0.94       337

# %% [markdown]
# ### 1.3. Mean Values

# %%
# Values used to train the model: X_mean, y_mean
# Values used to test the model: X_test_mean, y_test_mean

# Data Standardization -> Good practice working with KNN (based on the distance)
X_mean_KNN = preprocessing.StandardScaler().fit(X_mean).transform(X_mean.astype(float))
X_test_mean_KNN = preprocessing.StandardScaler().fit(X_test_mean).transform(X_test_mean.astype(float))

# %%
knn_accuracy(X_mean_KNN, y_mean, X_test_mean_KNN, y_test_mean, 10)
# Out:
# Value of k: 1 - Accuracy: 0.95
# Value of k: 2 - Accuracy: 0.94
# Value of k: 3 - Accuracy: 0.90
# Value of k: 4 - Accuracy: 0.88
# Value of k: 5 - Accuracy: 0.86
# Value of k: 6 - Accuracy: 0.85
# Value of k: 7 - Accuracy: 0.82
# Value of k: 8 - Accuracy: 0.79
# Value of k: 9 - Accuracy: 0.79

# %%
k = 2
#Train Model and Predict  
neigh_mean = KNeighborsClassifier(n_neighbors = k).fit(X_mean_KNN,y_mean)
y_hat_mean_KNN = neigh_mean.predict(X_test_mean_KNN)

# %%
k_fold_cv(X_mean_KNN, y_mean, 10, neigh_mean)
# Out:
# 'Accuracy: 0.9992537313432835'

# %%
evaluate_model(X_mean_KNN, y_mean, X_test_mean_KNN, y_test_mean, neigh_mean)
# Out:
# Train set Accuracy:  0.9992542878448919
# Test set Accuracy:  0.9434523809523809
# F1 score:  0.9555035128805621
# Recall 0's:  0.8625954198473282
# Recall 1's:  0.9951219512195122
# Jaccard index 0's:  0.8560606060606061
# Jaccard index 1's:  0.9147982062780269
#
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.86      0.92       131
#          1.0       0.92      1.00      0.96       205
#
#     accuracy                           0.94       336
#    macro avg       0.96      0.93      0.94       336
# weighted avg       0.95      0.94      0.94       336

# %% [markdown]
# ### 1.4. Median Values

# %%
# Values used to train the model: X_median, y_median
# Values used to test the model: X_test_median, y_test_median

# Data Standardization -> Good practice working with KNN (based on the distance)
X_median_KNN = preprocessing.StandardScaler().fit(X_median).transform(X_median.astype(float))
X_test_median_KNN = preprocessing.StandardScaler().fit(X_test_median).transform(X_test_median.astype(float))

# %%
knn_accuracy(X_median_KNN, y_median, X_test_median_KNN, y_test_median, 10)
# Out:
# Value of k: 1 - Accuracy: 0.95
# Value of k: 2 - Accuracy: 0.94
# Value of k: 3 - Accuracy: 0.90
# Value of k: 4 - Accuracy: 0.88
# Value of k: 5 - Accuracy: 0.86
# Value of k: 6 - Accuracy: 0.85
# Value of k: 7 - Accuracy: 0.84
# Value of k: 8 - Accuracy: 0.82
# Value of k: 9 - Accuracy: 0.80

# %%
k = 2
#Train Model and Predict  
neigh_median = KNeighborsClassifier(n_neighbors = k).fit(X_median_KNN,y_median)
y_hat_median_KNN = neigh_median.predict(X_test_median_KNN)

# %%
k_fold_cv(X_median_KNN, y_median, 10, neigh_median)
# Out:
# 'Accuracy: 0.9992537313432835'

# %%
evaluate_model(X_median_KNN, y_median, X_test_median_KNN, y_test_median, neigh_median)
# Out:
# Train set Accuracy:  0.9992542878448919
# Test set Accuracy:  0.9434523809523809
# F1 score:  0.9555035128805621
# Recall 0's:  0.8625954198473282
# Recall 1's:  0.9951219512195122
# Jaccard index 0's:  0.8560606060606061
# Jaccard index 1's:  0.9147982062780269
#
#
#               precision    recall  f1-score   support
#
#          0.0       0.99      0.86      0.92       131
#          1.0       0.92      1.00      0.96       205
#
#     accuracy                           0.94       336
#    macro avg       0.96      0.93      0.94       336
# weighted avg       0.95      0.94      0.94       336

# %% [markdown]
# ## 2. Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# ### 2.1. Drop Values

# %%
# Values used to train the model: X_drop, y_drop
# Values used to test the model: X_test_drop, y_test_drop

# Data Standardization (algorithm based on the distance)
X_drop_LR = preprocessing.StandardScaler().fit(X_drop).transform(X_drop.astype(float))
X_test_drop_LR = preprocessing.StandardScaler().fit(X_test_drop).transform(X_test_drop.astype(float))

# %%
# Train Model and Predict  
LR_drop = LogisticRegression(C=0.01, solver='liblinear').fit(X_drop_LR,y_drop)
y_hat_drop_LR = LR_drop.predict(X_test_drop_LR)

# Predict the probability of each class for a given input
y_hat_prob_drop_LR = LR_drop.predict_proba(X_test_drop_LR)

# %%
k_fold_cv(X_drop_LR, y_drop, 10, LR_drop)
# Out:
# 'Accuracy: 0.8749462365591398'

# %%
evaluate_model(X_drop_LR, y_drop, X_test_drop_LR, y_test_drop, LR_drop)
# Out:
# Train set Accuracy:  0.8745874587458746
# Test set Accuracy:  0.8552631578947368
# F1 score:  0.8735632183908045
# Recall 0's:  0.7105263157894737
# Recall 1's:  1.0
# Jaccard index 0's:  0.7105263157894737
# Jaccard index 1's:  0.7755102040816326
#
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.71      0.83        38
#          1.0       0.78      1.00      0.87        38
#
#     accuracy                           0.86        76
#    macro avg       0.89      0.86      0.85        76
# weighted avg       0.89      0.86      0.85        76

# %% [markdown]
# ### 2.2. Zero Values

# %%
# Values used to train the model: X_zero, y_zero
# Values used to test the model: X_test_zero, y_test_zero

# Data Standardization (algorithm based on the distance)
X_zero_LR = preprocessing.StandardScaler().fit(X_zero).transform(X_zero.astype(float))
X_test_zero_LR = preprocessing.StandardScaler().fit(X_test_zero).transform(X_test_zero.astype(float))

# %%
# Train Model and Predict  
LR_zero = LogisticRegression(C=0.01, solver='liblinear').fit(X_zero_LR,y_zero)
y_hat_zero_LR = LR_zero.predict(X_test_zero_LR)

# Predict the probability of each class for a given input
y_hat_prob_zero_LR = LR_zero.predict_proba(X_test_zero_LR)

# %%
evaluate_model(X_zero_LR, y_zero, X_test_zero_LR, y_test_zero, LR_zero)
# Out:
# Train set Accuracy:  0.7867756315007429
# Test set Accuracy:  0.7833827893175074
# F1 score:  0.8282352941176471
# Recall 0's:  0.6666666666666666
# Recall 1's:  0.8585365853658536
# Jaccard index 0's:  0.546583850931677
# Jaccard index 1's:  0.7068273092369478
#
#
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.67      0.71       132
#          1.0       0.80      0.86      0.83       205
#
#     accuracy                           0.78       337
#    macro avg       0.78      0.76      0.77       337
# weighted avg       0.78      0.78      0.78       337

# %% [markdown]
# ### 2.3. Mean Values

# %%
# Values used to train the model: X_mean, y_mean
# Values used to test the model: X_test_mean, y_test_mean

# Data Standardization (algorithm based on the distance)
X_mean_LR = preprocessing.StandardScaler().fit(X_mean).transform(X_mean.astype(float))
X_test_mean_LR = preprocessing.StandardScaler().fit(X_test_mean).transform(X_test_mean.astype(float))

# %%
# Train Model and Predict  
LR_mean = LogisticRegression(C=0.01, solver='liblinear').fit(X_mean_LR,y_mean)
y_hat_mean_LR = LR_mean.predict(X_test_mean_LR)

# Predict the probability of each class for a given input
y_hat_prob_mean_LR = LR_mean.predict_proba(X_test_mean_LR)

# %%
evaluate_model(X_mean_LR, y_mean, X_test_mean_LR, y_test_mean, LR_mean)
# Out:
# Train set Accuracy:  0.8135719612229679
# Test set Accuracy:  0.7738095238095238
# F1 score:  0.8248847926267282
# Recall 0's:  0.6183206106870229
# Recall 1's:  0.8731707317073171
# Jaccard index 0's:  0.5159235668789809
# Jaccard index 1's:  0.7019607843137254
#
#
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.62      0.68       131
#          1.0       0.78      0.87      0.82       205
#
#     accuracy                           0.77       336
#    macro avg       0.77      0.75      0.75       336
# weighted avg       0.77      0.77      0.77       336

# %% [markdown]
# ### 2.4. Median Values

# %%
# Values used to train the model: X_median, y_median
# Values used to test the model: X_test_median, y_test_median

# Data Standardization (algorithm based on the distance)
X_median_LR = preprocessing.StandardScaler().fit(X_median).transform(X_median.astype(float))
X_test_median_LR = preprocessing.StandardScaler().fit(X_test_median).transform(X_test_median.astype(float))

# %%
# Train Model and Predict  
LR_median = LogisticRegression(C=0.01, solver='liblinear').fit(X_median_LR,y_median)
y_hat_median_LR = LR_median.predict(X_test_median_LR)

# Predict the probability of each class for a given input
y_hat_prob_median_LR = LR_median.predict_proba(X_test_median_LR)

# %%
evaluate_model(X_median_LR, y_median, X_test_median_LR, y_test_median, LR_median)
# Out:
# Train set Accuracy:  0.8016405667412378
# Test set Accuracy:  0.7738095238095238
# F1 score:  0.8240740740740741
# Recall 0's:  0.6259541984732825
# Recall 1's:  0.8682926829268293
# Jaccard index 0's:  0.5189873417721519
# Jaccard index 1's:  0.7007874015748031
#
#
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.63      0.68       131
#          1.0       0.78      0.87      0.82       205
#
#     accuracy                           0.77       336
#    macro avg       0.77      0.75      0.75       336
# weighted avg       0.77      0.77      0.77       336

# %% [markdown]
# ## 3. Support Vector Machines

# %%
from sklearn import svm

# %%
# Model: svm.SVC(kernel='rbf')
# kernel='rbf'" where 'rbf' stands for radial basis function

# %% [markdown]
# ### 3.1. Drop Values

# %%
# Values used to train the model: X_drop, y_drop
# Values used to test the model: X_test_drop, y_test_drop

# Train Model and Predict 
svm_drop = svm.SVC(kernel='rbf').fit(X_drop, y_drop) 
y_hat_drop_SVM = svm_drop.predict(X_test_drop)

# %%
evaluate_model(X_drop, y_drop, X_test_drop, y_test_drop, svm_drop)
# Out:
# Train set Accuracy:  0.858085808580858
# Test set Accuracy:  0.7105263157894737
# F1 score:  0.744186046511628
# Recall 0's:  0.5789473684210527
# Recall 1's:  0.8421052631578947
# Jaccard index 0's:  0.5
# Jaccard index 1's:  0.5925925925925926
#
#
#               precision    recall  f1-score   support
#
#          0.0       0.79      0.58      0.67        38
#          1.0       0.67      0.84      0.74        38
#
#     accuracy                           0.71        76
#    macro avg       0.73      0.71      0.71        76
# weighted avg       0.73      0.71      0.71        76

# %% [markdown]
# ### 3.2. Zero Values

# %%
# Values used to train the model: X_zero, y_zero
# Values used to test the model: X_test_zero, y_test_zero

# Train Model and Predict  
svm_zero = svm.SVC(kernel='rbf').fit(X_zero, y_zero) 
y_hat_zero_SVM = svm_zero.predict(X_test_zero)

# %%
evaluate_model(X_zero, y_zero, X_test_zero, y_test_zero, svm_zero)
# Out:
# Train set Accuracy:  0.7927191679049034
# Test set Accuracy:  0.7685459940652819
# F1 score:  0.8326180257510729
# Recall 0's:  0.49242424242424243
# Recall 1's:  0.9463414634146341
# Jaccard index 0's:  0.45454545454545453
# Jaccard index 1's:  0.7132352941176471
#
#
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.49      0.62       132
#          1.0       0.74      0.95      0.83       205
#
#     accuracy                           0.77       337
#    macro avg       0.80      0.72      0.73       337
# weighted avg       0.79      0.77      0.75       337

# %% [markdown]
# ### 3.3. Mean Values

# %%
# Values used to train the model: X_mean, y_mean
# Values used to test the model: X_test_mean, y_test_mean

# Train Model and Predict  
svm_mean = svm.SVC(kernel='rbf').fit(X_mean, y_mean) 
y_hat_mean_SVM = svm_mean.predict(X_test_mean)

# %%
evaluate_model(X_mean, y_mean, X_test_mean, y_test_mean, svm_mean)
# Out:
# Train set Accuracy:  0.7390007457121551
# Test set Accuracy:  0.7142857142857143
# F1 score:  0.7847533632286996
# Recall 0's:  0.4961832061068702
# Recall 1's:  0.8536585365853658
# Jaccard index 0's:  0.40372670807453415
# Jaccard index 1's:  0.6457564575645757
#
#
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.50      0.58       131
#          1.0       0.73      0.85      0.78       205
#
#     accuracy                           0.71       336
#    macro avg       0.71      0.67      0.68       336
# weighted avg       0.71      0.71      0.70       336

# %% [markdown]
# ### 3.4. Median Values

# %%
# Values used to train the model: X_median, y_median
# Values used to test the model: X_test_median, y_test_median

# Train Model and Predict  
svm_median = svm.SVC(kernel='rbf').fit(X_median, y_median) 
y_hat_median_SVM = svm_median.predict(X_test_median)

# %%
evaluate_model(X_median, y_median, X_test_median, y_test_median, svm_median)
# Out:
# Train set Accuracy:  0.7554064131245339
# Test set Accuracy:  0.7232142857142857
# F1 score:  0.7937915742793791
# Recall 0's:  0.48854961832061067
# Recall 1's:  0.8731707317073171
# Jaccard index 0's:  0.40764331210191085
# Jaccard index 1's:  0.6580882352941176
#
#
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.49      0.58       131
#          1.0       0.73      0.87      0.79       205
#
#     accuracy                           0.72       336
#    macro avg       0.72      0.68      0.69       336
# weighted avg       0.72      0.72      0.71       336

# %% [markdown]
# ## 4. Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ### 4.1. Drop Values

# %%
# Values used to train the model: X_drop, y_drop
# Values used to test the model: X_test_drop, y_test_drop

# Train Model and Predict 
rfc_drop = RandomForestClassifier(n_estimators = 30, max_depth = 7, min_samples_leaf = 6).fit(X_drop , y_drop)
y_hat_drop_RF = rfc_drop.predict(X_test_drop)

# %%
evaluate_model(X_drop, y_drop, X_test_drop, y_test_drop, rfc_drop)
# Out:
# Train set Accuracy:  0.9933993399339934
# Test set Accuracy:  0.9473684210526315
# F1 score:  0.9500000000000001
# Recall 0's:  0.8947368421052632
# Recall 1's:  1.0
# Jaccard index 0's:  0.8947368421052632
# Jaccard index 1's:  0.9047619047619048
#
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.89      0.94        38
#          1.0       0.90      1.00      0.95        38
#
#     accuracy                           0.95        76
#    macro avg       0.95      0.95      0.95        76
# weighted avg       0.95      0.95      0.95        76

# %% [markdown]
# ### 4.2. Zero Values

# %%
# Values used to train the model: X_zero, y_zero
# Values used to test the model: X_test_zero, y_test_zero

# Train Model and Predict  
rfc_zero = RandomForestClassifier(n_estimators = 30, max_depth = 7, min_samples_leaf = 6).fit(X_zero , y_zero)
y_hat_zero_RF = rfc_zero.predict(X_test_zero)

# %%
evaluate_model(X_zero, y_zero, X_test_zero, y_test_zero, rfc_zero)
# Out:
# Train set Accuracy:  0.9227340267459139
# Test set Accuracy:  0.8605341246290801
# F1 score:  0.8943820224719102
# Recall 0's:  0.6893939393939394
# Recall 1's:  0.9707317073170731
# Jaccard index 0's:  0.6594202898550725
# Jaccard index 1's:  0.8089430894308943
#
#
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.69      0.79       132
#          1.0       0.83      0.97      0.89       205
#
#     accuracy                           0.86       337
#    macro avg       0.88      0.83      0.84       337
# weighted avg       0.87      0.86      0.86       337

# %% [markdown]
# ### 4.3. Mean Values

# %%
# Values used to train the model: X_mean, y_mean
# Values used to test the model: X_test_mean, y_test_mean

# Train Model and Predict 
rfc_mean = RandomForestClassifier(n_estimators = 30, max_depth = 7, min_samples_leaf = 6).fit(X_mean , y_mean)
y_hat_mean_RF = rfc_mean.predict(X_test_mean)

# %%
evaluate_model(X_mean, y_mean, X_test_mean, y_test_mean, rfc_mean)
# Out:
# Train set Accuracy:  0.935868754660701
# Test set Accuracy:  0.8720238095238095
# F1 score:  0.9011494252873563
# Recall 0's:  0.7404580152671756
# Recall 1's:  0.9560975609756097
# Jaccard index 0's:  0.6928571428571428
# Jaccard index 1's:  0.8200836820083682
#
#
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.74      0.82       131
#          1.0       0.85      0.96      0.90       205
#
#     accuracy                           0.87       336
#    macro avg       0.88      0.85      0.86       336
# weighted avg       0.88      0.87      0.87       336

# %% [markdown]
# ### 4.4. Median Values

# %%
# Values used to train the model: X_median, y_median
# Values used to test the model: X_test_median, y_test_median

# Train Model and Predict 
rfc_median = RandomForestClassifier(n_estimators = 30, max_depth = 7, min_samples_leaf = 6).fit(X_median , y_median)
y_hat_median_RF = rfc_median.predict(X_test_median)

# %%
evaluate_model(X_median, y_median, X_test_median, y_test_median, rfc_median)
# Out:
# Train set Accuracy:  0.9291573452647278
# Test set Accuracy:  0.8630952380952381
# F1 score:  0.8940092165898618
# Recall 0's:  0.732824427480916
# Recall 1's:  0.9463414634146341
# Jaccard index 0's:  0.676056338028169
# Jaccard index 1's:  0.8083333333333333
#
#
#               precision    recall  f1-score   support
#
#          0.0       0.90      0.73      0.81       131
#          1.0       0.85      0.95      0.89       205
#
#     accuracy                           0.86       336
#    macro avg       0.87      0.84      0.85       336
# weighted avg       0.87      0.86      0.86       336

# %% [markdown]
# ## 5. Tree Decision

# %%
from sklearn.tree import DecisionTreeClassifier
import sklearn.tree as tree

# %% [markdown]
# ### 5.1. Drop Values

# %%
# Values used to train the model: X_drop, y_drop
# Values used to test the model: X_test_drop, y_test_drop

# Train Model and Predict 
tree_drop = DecisionTreeClassifier(criterion = "entropy", max_depth = 4).fit(X_drop, y_drop)
y_hat_drop_tree = tree_drop.predict(X_test_drop)

# %%
evaluate_model(X_drop, y_drop, X_test_drop, y_test_drop, tree_drop)
# Out:
# Train set Accuracy:  0.9570957095709571
# Test set Accuracy:  0.8157894736842105
# F1 score:  0.8444444444444443
# Recall 0's:  0.631578947368421
# Recall 1's:  1.0
# Jaccard index 0's:  0.631578947368421
# Jaccard index 1's:  0.7307692307692307
#
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.63      0.77        38
#          1.0       0.73      1.00      0.84        38
#
#     accuracy                           0.82        76
#    macro avg       0.87      0.82      0.81        76
# weighted avg       0.87      0.82      0.81        76

# %% [markdown]
# ### 5.2. Zero Values

# %%
# Values used to train the model: X_zero, y_zero
# Values used to test the model: X_test_zero, y_test_zero

# Train Model and Predict 
tree_zero = DecisionTreeClassifier(criterion = "entropy", max_depth = 4).fit(X_zero, y_zero)
y_hat_zero_tree = tree_zero.predict(X_test_zero)

# %%
evaluate_model(X_zero, y_zero, X_test_zero, y_test_zero, tree_zero)
# Out:
# Train set Accuracy:  0.7867756315007429
# Test set Accuracy:  0.7210682492581603
# F1 score:  0.7956521739130434
# Recall 0's:  0.45454545454545453
# Recall 1's:  0.8926829268292683
# Jaccard index 0's:  0.38961038961038963
# Jaccard index 1's:  0.6606498194945848
#
#
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.45      0.56       132
#          1.0       0.72      0.89      0.80       205
#
#     accuracy                           0.72       337
#    macro avg       0.72      0.67      0.68       337
# weighted avg       0.72      0.72      0.70       337

# %% [markdown]
# ### 5.3. Mean Values

# %%
# Values used to train the model: X_mean, y_mean
# Values used to test the model: X_test_mean, y_test_mean

# Train Model and Predict 
tree_mean = DecisionTreeClassifier(criterion = "entropy", max_depth = 4).fit(X_mean, y_mean)
y_hat_mean_tree = tree_mean.predict(X_test_mean)

# %%
evaluate_model(X_mean, y_mean, X_test_mean, y_test_mean, tree_mean)
# Out:
# Train set Accuracy:  0.773303504847129
# Test set Accuracy:  0.7351190476190477
# F1 score:  0.802660753880266
# Recall 0's:  0.5038167938931297
# Recall 1's:  0.8829268292682927
# Jaccard index 0's:  0.4258064516129032
# Jaccard index 1's:  0.6703703703703704
#
#
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.50      0.60       131
#          1.0       0.74      0.88      0.80       205
#
#     accuracy                           0.74       336
#    macro avg       0.73      0.69      0.70       336
# weighted avg       0.73      0.74      0.72       336

# %% [markdown]
# ### 5.4. Median Values

# %%
# Values used to train the model: X_median, y_median
# Values used to test the model: X_test_median, y_test_median

# Train Model and Predict 
tree_median = DecisionTreeClassifier(criterion = "entropy", max_depth = 4).fit(X_median, y_median)
y_hat_median_tree = tree_median.predict(X_test_median)

# %%
evaluate_model(X_median, y_median, X_test_median, y_test_median, tree_median)
# Out:
# Train set Accuracy:  0.750186428038777
# Test set Accuracy:  0.7142857142857143
# F1 score:  0.7735849056603773
# Recall 0's:  0.5801526717557252
# Recall 1's:  0.8
# Jaccard index 0's:  0.4418604651162791
# Jaccard index 1's:  0.6307692307692307
#
#
#               precision    recall  f1-score   support
#
#          0.0       0.65      0.58      0.61       131
#          1.0       0.75      0.80      0.77       205
#
#     accuracy                           0.71       336
#    macro avg       0.70      0.69      0.69       336
# weighted avg       0.71      0.71      0.71       336
